# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/all unlabeled/oral_normal_3080.jpg
# /kaggle/input/all unlabeled/oral_normal_3357.jpg
# /kaggle/input/all unlabeled/oral_normal_0983.jpg
# /kaggle/input/all unlabeled/oral_normal_1124.jpg
# /kaggle/input/all unlabeled/oral_normal_3829.jpg
# /kaggle/input/all unlabeled/oral_normal_3515.jpg
# /kaggle/input/all unlabeled/oral_normal_1324.jpg
# /kaggle/input/all unlabeled/oral_normal_4162.jpg
# /kaggle/input/all unlabeled/oral_scc_0771.jpg
# /kaggle/input/all unlabeled/oral_scc_0707.jpg
# /kaggle/input/all unlabeled/oral_scc_3093.jpg
# /kaggle/input/all unlabeled/oral_normal_0952.jpg
# /kaggle/input/all unlabeled/oral_normal_4147.jpg
# /kaggle/input/all unlabeled/oral_scc_0480.jpg
# /kaggle/input/all unlabeled/oral_scc_0654.jpg
# /kaggle/input/all unlabeled/oral_normal_1627.jpg
# /kaggle/input/all unlabeled/oral_scc_0620.jpg
# /kaggle/input/all unlabeled/oral_normal_1034.jpg
# /kaggle/input/all unlabeled/oral_scc_3567.jpg
# /kaggle/input/all unlabeled/oral_scc_1208.jpg
# /kaggle/input/all unlabeled/oral_scc_0761.jpg
# /kaggle/input/all unlabeled/oral_normal_4252.jpg
# /kaggle/input/all unlabeled/oral_scc_2566.jpg
# /kaggle/input/all unlabeled/oral_normal_1818.jpg
# /kaggle/input/all unlabeled/oral_normal_4061.jpg
# /kaggle/input/all unlabeled/oral_scc_1952.jpg
# /kaggle/input/all unlabeled/oral_scc_4835.jpg
# /kaggle/input/all unlabeled/oral_scc_3963.jpg
# /kaggle/input/all unlabeled/oral_scc_3084.jpg
# /kaggle/input/all unlabeled/oral_scc_1822.jpg
# /kaggle/input/all unlabeled/oral_normal_1428.jpg
# /kaggle/input/all unlabeled/oral_scc_3775.jpg
# /kaggle/input/all unlabeled/oral_normal_3741.jpg
# /kaggle/input/all unlabeled/oral_scc_0895.jpg
# /kaggle/input/all unlabeled/oral_normal_1629.jpg
# /kaggle/input/all unlabeled/oral_scc_4225.jpg
# /kaggle/input/all unlabeled/oral_scc_2004.jpg
# /kaggle/input/all unlabeled/oral_normal_0473.jpg
# /kaggle/input/all unlabeled/oral_scc_1243.jpg
# /kaggle/input/all unlabeled/oral_normal_1212.jpg
# /kaggle/input/all unlabeled/oral_scc_1322.jpg
# /kaggle/input/all unlabeled/oral_scc_4960.jpg
# /kaggle/input/all unlabeled/oral_scc_0146.jpg
# /kaggle/input/all unlabeled/oral_scc_2028.jpg
# /kaggle/input/all unlabeled/oral_scc_1149.jpg
# /kaggle/input/all unlabeled/oral_scc_0991.jpg
# /kaggle/input/all unlabeled/oral_scc_0869.jpg
# /kaggle/input/all unlabeled/oral_scc_1459.jpg
# /kaggle/input/all unlabeled/oral_scc_4538.jpg
# /kaggle/input/all unlabeled/oral_normal_3830.jpg
# /kaggle/input/all unlabeled/oral_normal_3653.jpg
# /kaggle/input/all unlabeled/oral_normal_3867.jpg
# /kaggle/input/all unlabeled/oral_normal_0062.jpg
# /kaggle/input/all unlabeled/oral_scc_1242.jpg
# /kaggle/input/all unlabeled/oral_normal_3211.jpg
# /kaggle/input/all unlabeled/oral_normal_4047.jpg
# /kaggle/input/all unlabeled/oral_normal_4115.jpg
# /kaggle/input/all unlabeled/oral_normal_1498.jpg
# /kaggle/input/all unlabeled/oral_scc_0264.jpg
# /kaggle/input/all unlabeled/oral_normal_1107.jpg
# /kaggle/input/all unlabeled/oral_normal_3715.jpg
# /kaggle/input/all unlabeled/oral_normal_2383.jpg
# /kaggle/input/all unlabeled/oral_scc_4602.jpg
# /kaggle/input/all unlabeled/oral_scc_2472.jpg
# /kaggle/input/all unlabeled/oral_normal_3723.jpg
# /kaggle/input/all unlabeled/oral_scc_4252.jpg
# /kaggle/input/all unlabeled/oral_scc_4752.jpg
# /kaggle/input/all unlabeled/oral_scc_1116.jpg
# /kaggle/input/all unlabeled/oral_normal_2527.jpg
# /kaggle/input/all unlabeled/oral_normal_1123.jpg
# /kaggle/input/all unlabeled/oral_scc_1644.jpg
# /kaggle/input/all unlabeled/oral_scc_2036.jpg
# /kaggle/input/all unlabeled/oral_scc_4820.jpg
# /kaggle/input/all unlabeled/oral_scc_2890.jpg
# /kaggle/input/all unlabeled/oral_normal_1183.jpg
# /kaggle/input/all unlabeled/oral_normal_0794.jpg
# /kaggle/input/all unlabeled/oral_normal_3989.jpg
# /kaggle/input/all unlabeled/oral_normal_4053.jpg
# /kaggle/input/all unlabeled/oral_normal_0676.jpg
# /kaggle/input/all unlabeled/oral_normal_1436.jpg
# /kaggle/input/all unlabeled/oral_normal_2107.jpg
# /kaggle/input/all unlabeled/oral_scc_1619.jpg
# /kaggle/input/all unlabeled/oral_normal_2847.jpg
# /kaggle/input/all unlabeled/oral_scc_2667.jpg
# /kaggle/input/all unlabeled/oral_normal_4176.jpg
# /kaggle/input/all unlabeled/oral_scc_3332.jpg
# /kaggle/input/all unlabeled/oral_scc_3564.jpg
# /kaggle/input/all unlabeled/oral_normal_2260.jpg
# /kaggle/input/all unlabeled/oral_scc_4509.jpg
# /kaggle/input/all unlabeled/oral_scc_1038.jpg
# /kaggle/input/all unlabeled/oral_normal_4426.jpg
# /kaggle/input/all unlabeled/oral_scc_2194.jpg
# /kaggle/input/all unlabeled/oral_normal_3496.jpg
# /kaggle/input/all unlabeled/oral_normal_2691.jpg
# /kaggle/input/all unlabeled/oral_scc_3434.jpg
# /kaggle/input/all unlabeled/oral_scc_4648.jpg
# /kaggle/input/all unlabeled/oral_normal_2702.jpg
# /kaggle/input/all unlabeled/oral_scc_1937.jpg
# /kaggle/input/all unlabeled/oral_scc_3364.jpg
# /kaggle/input/all unlabeled/oral_scc_2828.jpg
# /kaggle/input/all unlabeled/oral_scc_2073.jpg
# /kaggle/input/all unlabeled/oral_scc_3109.jpg
# /kaggle/input/all unlabeled/oral_normal_4957.jpg
# /kaggle/input/all unlabeled/oral_scc_0508.jpg
# /kaggle/input/all unlabeled/oral_normal_1144.jpg
# /kaggle/input/all unlabeled/oral_scc_4314.jpg
# /kaggle/input/all unlabeled/oral_scc_0717.jpg
# /kaggle/input/all unlabeled/oral_scc_1867.jpg
# /kaggle/input/all unlabeled/oral_normal_1606.jpg
# /kaggle/input/all unlabeled/oral_normal_4574.jpg
# /kaggle/input/all unlabeled/oral_scc_2368.jpg
# /kaggle/input/all unlabeled/oral_scc_4551.jpg
# /kaggle/input/all unlabeled/oral_scc_4693.jpg
# /kaggle/input/all unlabeled/oral_normal_3482.jpg
# /kaggle/input/all unlabeled/oral_normal_3942.jpg
# /kaggle/input/all unlabeled/oral_normal_1346.jpg
# /kaggle/input/all unlabeled/oral_normal_0094.jpg
# /kaggle/input/all unlabeled/oral_scc_2948.jpg
# /kaggle/input/all unlabeled/oral_normal_3210.jpg
# /kaggle/input/all unlabeled/oral_normal_1119.jpg
# /kaggle/input/all unlabeled/oral_normal_4601.jpg
# /kaggle/input/all unlabeled/oral_normal_4662.jpg
# /kaggle/input/all unlabeled/oral_normal_4684.jpg
# /kaggle/input/all unlabeled/oral_normal_0139.jpg
# /kaggle/input/all unlabeled/oral_scc_0338.jpg
# /kaggle/input/all unlabeled/oral_scc_1985.jpg
# /kaggle/input/all unlabeled/oral_normal_4959.jpg
# /kaggle/input/all unlabeled/oral_normal_3150.jpg
# /kaggle/input/all unlabeled/oral_normal_1086.jpg
# /kaggle/input/all unlabeled/oral_normal_2530.jpg
# /kaggle/input/all unlabeled/oral_scc_4370.jpg
# /kaggle/input/all unlabeled/oral_normal_2528.jpg
# /kaggle/input/all unlabeled/oral_normal_4245.jpg
# /kaggle/input/all unlabeled/oral_scc_4347.jpg
# /kaggle/input/all unlabeled/oral_scc_1231.jpg
# /kaggle/input/all unlabeled/oral_scc_4676.jpg
# /kaggle/input/all unlabeled/oral_normal_0504.jpg
# /kaggle/input/all unlabeled/oral_normal_2947.jpg
# /kaggle/input/all unlabeled/oral_normal_1662.jpg
# /kaggle/input/all unlabeled/oral_normal_3132.jpg
# /kaggle/input/all unlabeled/oral_scc_0757.jpg
# /kaggle/input/all unlabeled/oral_normal_2882.jpg
# /kaggle/input/all unlabeled/oral_scc_0739.jpg
# /kaggle/input/all unlabeled/oral_scc_0208.jpg
# /kaggle/input/all unlabeled/oral_scc_1050.jpg
# /kaggle/input/all unlabeled/oral_scc_4731.jpg
# /kaggle/input/all unlabeled/oral_scc_1053.jpg
# /kaggle/input/all unlabeled/oral_normal_3483.jpg
# /kaggle/input/all unlabeled/oral_normal_4381.jpg
# /kaggle/input/all unlabeled/oral_scc_2242.jpg
# /kaggle/input/all unlabeled/oral_normal_2779.jpg
# /kaggle/input/all unlabeled/oral_normal_2141.jpg
# /kaggle/input/all unlabeled/oral_scc_2880.jpg
# /kaggle/input/all unlabeled/oral_normal_0536.jpg
# /kaggle/input/all unlabeled/oral_normal_3088.jpg
# /kaggle/input/all unlabeled/oral_scc_2814.jpg
# /kaggle/input/all unlabeled/oral_normal_3711.jpg
# /kaggle/input/all unlabeled/oral_scc_0321.jpg
# /kaggle/input/all unlabeled/oral_normal_4453.jpg
# /kaggle/input/all unlabeled/oral_normal_1808.jpg
# /kaggle/input/all unlabeled/oral_normal_1186.jpg
# /kaggle/input/all unlabeled/oral_scc_2864.jpg
# /kaggle/input/all unlabeled/oral_normal_3472.jpg
# /kaggle/input/all unlabeled/oral_scc_2860.jpg
# /kaggle/input/all unlabeled/oral_normal_1239.jpg
# /kaggle/input/all unlabeled/oral_normal_4117.jpg
# /kaggle/input/all unlabeled/oral_scc_1063.jpg
# /kaggle/input/all unlabeled/oral_normal_1122.jpg
# /kaggle/input/all unlabeled/oral_normal_4673.jpg
# /kaggle/input/all unlabeled/oral_normal_1418.jpg
# /kaggle/input/all unlabeled/oral_scc_2741.jpg
# /kaggle/input/all unlabeled/oral_scc_2630.jpg
# /kaggle/input/all unlabeled/oral_scc_1848.jpg
# /kaggle/input/all unlabeled/oral_scc_0477.jpg
# /kaggle/input/all unlabeled/oral_normal_4958.jpg
# /kaggle/input/all unlabeled/oral_normal_0958.jpg
# /kaggle/input/all unlabeled/oral_normal_4123.jpg
# /kaggle/input/all unlabeled/oral_scc_2702.jpg
# /kaggle/input/all unlabeled/oral_scc_0754.jpg
# /kaggle/input/all unlabeled/oral_scc_3521.jpg
# /kaggle/input/all unlabeled/oral_scc_2309.jpg
# /kaggle/input/all unlabeled/oral_normal_1568.jpg
# /kaggle/input/all unlabeled/oral_scc_3152.jpg
# /kaggle/input/all unlabeled/oral_scc_2499.jpg
# /kaggle/input/all unlabeled/oral_normal_2798.jpg
# /kaggle/input/all unlabeled/oral_scc_1041.jpg
# /kaggle/input/all unlabeled/oral_normal_3047.jpg
# /kaggle/input/all unlabeled/oral_normal_1061.jpg
# /kaggle/input/all unlabeled/oral_scc_1869.jpg
# /kaggle/input/all unlabeled/oral_scc_4961.jpg
# /kaggle/input/all unlabeled/oral_scc_1160.jpg
# /kaggle/input/all unlabeled/oral_scc_4541.jpg
# /kaggle/input/all unlabeled/oral_normal_4833.jpg
# /kaggle/input/all unlabeled/oral_scc_2759.jpg
# /kaggle/input/all unlabeled/oral_scc_1647.jpg
# /kaggle/input/all unlabeled/oral_scc_4161.jpg
# /kaggle/input/all unlabeled/oral_scc_4141.jpg
# /kaggle/input/all unlabeled/oral_normal_3255.jpg
# /kaggle/input/all unlabeled/oral_normal_2588.jpg
# /kaggle/input/all unlabeled/oral_normal_3429.jpg
# /kaggle/input/all unlabeled/oral_normal_0769.jpg
# /kaggle/input/all unlabeled/oral_normal_4412.jpg
# /kaggle/input/all unlabeled/oral_normal_2531.jpg
# /kaggle/input/all unlabeled/oral_normal_0876.jpg
# /kaggle/input/all unlabeled/oral_normal_3940.jpg
# /kaggle/input/all unlabeled/oral_scc_0607.jpg
# /kaggle/input/all unlabeled/oral_scc_4794.jpg
# /kaggle/input/all unlabeled/oral_normal_4563.jpg
# /kaggle/input/all unlabeled/oral_scc_4548.jpg
# /kaggle/input/all unlabeled/oral_normal_3292.jpg
# /kaggle/input/all unlabeled/oral_scc_4610.jpg
# /kaggle/input/all unlabeled/oral_scc_1267.jpg
# /kaggle/input/all unlabeled/oral_normal_1923.jpg
# /kaggle/input/all unlabeled/oral_normal_0746.jpg
# /kaggle/input/all unlabeled/oral_normal_2446.jpg
# /kaggle/input/all unlabeled/oral_scc_3121.jpg
# /kaggle/input/all unlabeled/oral_normal_2226.jpg
# /kaggle/input/all unlabeled/oral_normal_4765.jpg
# /kaggle/input/all unlabeled/oral_scc_0833.jpg
# /kaggle/input/all unlabeled/oral_normal_3648.jpg
# /kaggle/input/all unlabeled/oral_normal_4277.jpg
# /kaggle/input/all unlabeled/oral_scc_3288.jpg
# /kaggle/input/all unlabeled/oral_scc_3390.jpg
# /kaggle/input/all unlabeled/oral_scc_2722.jpg
# /kaggle/input/all unlabeled/oral_normal_1584.jpg
# /kaggle/input/all unlabeled/oral_scc_2783.jpg
# /kaggle/input/all unlabeled/oral_scc_4637.jpg
# /kaggle/input/all unlabeled/oral_scc_2112.jpg
# /kaggle/input/all unlabeled/oral_scc_1091.jpg
# /kaggle/input/all unlabeled/oral_normal_3596.jpg
# /kaggle/input/all unlabeled/oral_scc_1104.jpg
# /kaggle/input/all unlabeled/oral_normal_1781.jpg
# /kaggle/input/all unlabeled/oral_normal_1291.jpg
# /kaggle/input/all unlabeled/oral_normal_1625.jpg
# /kaggle/input/all unlabeled/oral_scc_3261.jpg
# /kaggle/input/all unlabeled/oral_normal_0674.jpg
# /kaggle/input/all unlabeled/oral_normal_1872.jpg
# /kaggle/input/all unlabeled/oral_normal_0169.jpg
# /kaggle/input/all unlabeled/oral_scc_0302.jpg
# /kaggle/input/all unlabeled/oral_scc_4256.jpg
# /kaggle/input/all unlabeled/oral_normal_4706.jpg
# /kaggle/input/all unlabeled/oral_scc_0171.jpg
# /kaggle/input/all unlabeled/oral_scc_2192.jpg
# /kaggle/input/all unlabeled/oral_scc_1173.jpg
# /kaggle/input/all unlabeled/oral_scc_4750.jpg
# /kaggle/input/all unlabeled/oral_normal_0080.jpg
# /kaggle/input/all unlabeled/oral_scc_1631.jpg
# /kaggle/input/all unlabeled/oral_normal_1840.jpg
# /kaggle/input/all unlabeled/oral_scc_1815.jpg
# /kaggle/input/all unlabeled/oral_scc_1253.jpg
# /kaggle/input/all unlabeled/oral_scc_0344.jpg
# /kaggle/input/all unlabeled/oral_scc_4136.jpg
# /kaggle/input/all unlabeled/oral_normal_0976.jpg
# /kaggle/input/all unlabeled/oral_normal_3310.jpg
# /kaggle/input/all unlabeled/oral_normal_2599.jpg
# /kaggle/input/all unlabeled/oral_scc_3142.jpg
# /kaggle/input/all unlabeled/oral_scc_1526.jpg
# /kaggle/input/all unlabeled/oral_scc_0419.jpg
# /kaggle/input/all unlabeled/oral_scc_1874.jpg
# /kaggle/input/all unlabeled/oral_scc_0080.jpg
# /kaggle/input/all unlabeled/oral_scc_2335.jpg
# /kaggle/input/all unlabeled/oral_normal_0090.jpg
# /kaggle/input/all unlabeled/oral_normal_1087.jpg
# /kaggle/input/all unlabeled/oral_scc_4034.jpg
# /kaggle/input/all unlabeled/oral_normal_0866.jpg
# /kaggle/input/all unlabeled/oral_scc_1810.jpg
# /kaggle/input/all unlabeled/oral_scc_1746.jpg
# /kaggle/input/all unlabeled/oral_normal_4215.jpg
# /kaggle/input/all unlabeled/oral_scc_2003.jpg
# /kaggle/input/all unlabeled/oral_scc_4866.jpg
# /kaggle/input/all unlabeled/oral_scc_0108.jpg
# /kaggle/input/all unlabeled/oral_normal_3557.jpg
# /kaggle/input/all unlabeled/oral_normal_4756.jpg
# /kaggle/input/all unlabeled/oral_normal_4714.jpg
# /kaggle/input/all unlabeled/oral_scc_3164.jpg
# /kaggle/input/all unlabeled/oral_normal_0441.jpg
# /kaggle/input/all unlabeled/oral_normal_0190.jpg
# /kaggle/input/all unlabeled/oral_normal_4031.jpg
# /kaggle/input/all unlabeled/oral_normal_0312.jpg
# /kaggle/input/all unlabeled/oral_scc_1864.jpg
# /kaggle/input/all unlabeled/oral_normal_3186.jpg
# /kaggle/input/all unlabeled/oral_normal_3615.jpg
# /kaggle/input/all unlabeled/oral_scc_4621.jpg
# /kaggle/input/all unlabeled/oral_normal_4744.jpg
# /kaggle/input/all unlabeled/oral_normal_0217.jpg
# /kaggle/input/all unlabeled/oral_scc_0985.jpg
# /kaggle/input/all unlabeled/oral_normal_1386.jpg
# /kaggle/input/all unlabeled/oral_normal_3272.jpg
# /kaggle/input/all unlabeled/oral_scc_1176.jpg
# /kaggle/input/all unlabeled/oral_normal_0295.jpg
# /kaggle/input/all unlabeled/oral_normal_4279.jpg
# /kaggle/input/all unlabeled/oral_normal_2657.jpg
# /kaggle/input/all unlabeled/oral_normal_3464.jpg
# /kaggle/input/all unlabeled/oral_scc_1438.jpg
# /kaggle/input/all unlabeled/oral_normal_2164.jpg
# /kaggle/input/all unlabeled/oral_scc_0116.jpg
# /kaggle/input/all unlabeled/oral_scc_0945.jpg
# /kaggle/input/all unlabeled/oral_normal_0279.jpg
# /kaggle/input/all unlabeled/oral_scc_4081.jpg
# /kaggle/input/all unlabeled/oral_normal_0218.jpg
# /kaggle/input/all unlabeled/oral_normal_0376.jpg
# /kaggle/input/all unlabeled/oral_scc_3961.jpg
# /kaggle/input/all unlabeled/oral_normal_0191.jpg
# /kaggle/input/all unlabeled/oral_scc_0645.bak.jpg
# /kaggle/input/all unlabeled/oral_scc_3149.jpg
# /kaggle/input/all unlabeled/oral_normal_3813.jpg
# /kaggle/input/all unlabeled/oral_normal_3416.jpg
# /kaggle/input/all unlabeled/oral_normal_4101.jpg
# /kaggle/input/all unlabeled/oral_normal_2416.jpg
# /kaggle/input/all unlabeled/oral_normal_4611.jpg
# /kaggle/input/all unlabeled/oral_normal_2780.jpg
# /kaggle/input/all unlabeled/oral_normal_0830.jpg
# /kaggle/input/all unlabeled/oral_scc_1716.jpg
# /kaggle/input/all unlabeled/oral_normal_0611.jpg
# /kaggle/input/all unlabeled/oral_normal_1229.jpg
# /kaggle/input/all unlabeled/oral_normal_4064.jpg
# /kaggle/input/all unlabeled/oral_scc_2251.jpg
# /kaggle/input/all unlabeled/oral_scc_0472.jpg
# /kaggle/input/all unlabeled/oral_scc_1514.jpg
# /kaggle/input/all unlabeled/oral_scc_2436.jpg
# /kaggle/input/all unlabeled/oral_normal_2786.jpg
# /kaggle/input/all unlabeled/oral_normal_4211.jpg
# /kaggle/input/all unlabeled/oral_normal_2939.jpg
# /kaggle/input/all unlabeled/oral_scc_4093.jpg
# /kaggle/input/all unlabeled/oral_scc_0943.jpg
# /kaggle/input/all unlabeled/oral_normal_0708.jpg
# /kaggle/input/all unlabeled/oral_normal_0378.jpg
# /kaggle/input/all unlabeled/oral_normal_3810.jpg
# /kaggle/input/all unlabeled/oral_normal_1181.jpg
# /kaggle/input/all unlabeled/oral_scc_0328.jpg
# /kaggle/input/all unlabeled/oral_normal_3546.jpg
# /kaggle/input/all unlabeled/oral_scc_2222.jpg
# /kaggle/input/all unlabeled/oral_normal_3055.jpg
# /kaggle/input/all unlabeled/oral_scc_4011.jpg
# /kaggle/input/all unlabeled/oral_normal_1793.jpg
# /kaggle/input/all unlabeled/oral_scc_1766.jpg
# /kaggle/input/all unlabeled/oral_scc_3055.jpg
# /kaggle/input/all unlabeled/oral_scc_2312.jpg
# /kaggle/input/all unlabeled/oral_scc_4912.jpg
# /kaggle/input/all unlabeled/oral_scc_1061.jpg
# /kaggle/input/all unlabeled/oral_normal_1842.jpg
# /kaggle/input/all unlabeled/oral_scc_2811.jpg
# /kaggle/input/all unlabeled/oral_scc_3353.jpg
# /kaggle/input/all unlabeled/oral_normal_4256.jpg
# /kaggle/input/all unlabeled/oral_normal_0921.jpg
# /kaggle/input/all unlabeled/oral_scc_0105.jpg
# /kaggle/input/all unlabeled/oral_normal_2895.jpg
# /kaggle/input/all unlabeled/oral_scc_4964.jpg
# /kaggle/input/all unlabeled/oral_scc_0268.jpg
# /kaggle/input/all unlabeled/oral_normal_2635.jpg
# /kaggle/input/all unlabeled/oral_normal_4234.jpg
# /kaggle/input/all unlabeled/oral_normal_1969.jpg
# /kaggle/input/all unlabeled/oral_scc_3710.jpg
# /kaggle/input/all unlabeled/oral_scc_0566.jpg
# /kaggle/input/all unlabeled/oral_normal_4536.jpg
# /kaggle/input/all unlabeled/oral_scc_2858.jpg
# /kaggle/input/all unlabeled/oral_normal_3850.jpg
# /kaggle/input/all unlabeled/oral_scc_4947.jpg
# /kaggle/input/all unlabeled/oral_scc_3867.jpg
# /kaggle/input/all unlabeled/oral_scc_2381.jpg
# /kaggle/input/all unlabeled/oral_scc_1842.jpg
# /kaggle/input/all unlabeled/oral_normal_3069.jpg
# /kaggle/input/all unlabeled/oral_scc_3387.jpg
# /kaggle/input/all unlabeled/oral_normal_0022.jpg
# /kaggle/input/all unlabeled/oral_normal_0991.jpg
# /kaggle/input/all unlabeled/oral_scc_2875.jpg
# /kaggle/input/all unlabeled/oral_normal_2712.jpg
# /kaggle/input/all unlabeled/oral_scc_3255.jpg
# /kaggle/input/all unlabeled/oral_normal_3532.jpg
# /kaggle/input/all unlabeled/oral_normal_1032.jpg
# /kaggle/input/all unlabeled/oral_scc_4978.jpg
# /kaggle/input/all unlabeled/oral_normal_4742.jpg
# /kaggle/input/all unlabeled/oral_scc_1035.jpg
# /kaggle/input/all unlabeled/oral_normal_0436.jpg
# /kaggle/input/all unlabeled/oral_normal_1634.jpg
# /kaggle/input/all unlabeled/oral_normal_1779.jpg
# /kaggle/input/all unlabeled/oral_scc_4394.jpg
# /kaggle/input/all unlabeled/oral_scc_2459.jpg
# /kaggle/input/all unlabeled/oral_normal_2957.jpg
# /kaggle/input/all unlabeled/oral_scc_1067.jpg
# /kaggle/input/all unlabeled/oral_scc_0027.jpg
# /kaggle/input/all unlabeled/oral_normal_3631.jpg
# /kaggle/input/all unlabeled/oral_normal_1341.jpg
# /kaggle/input/all unlabeled/oral_scc_1304.jpg
# /kaggle/input/all unlabeled/oral_normal_1962.jpg
# /kaggle/input/all unlabeled/oral_scc_4049.jpg
# /kaggle/input/all unlabeled/oral_scc_0979.jpg
# /kaggle/input/all unlabeled/oral_scc_0298.jpg
# /kaggle/input/all unlabeled/oral_normal_3630.jpg
# /kaggle/input/all unlabeled/oral_scc_4084.jpg
# /kaggle/input/all unlabeled/oral_scc_2265.jpg
# /kaggle/input/all unlabeled/oral_normal_1460.jpg
# /kaggle/input/all unlabeled/oral_scc_0821.jpg
# /kaggle/input/all unlabeled/oral_normal_1736.jpg
# /kaggle/input/all unlabeled/oral_normal_1757.jpg
# /kaggle/input/all unlabeled/oral_scc_0359.jpg
# /kaggle/input/all unlabeled/oral_scc_2571.jpg
# /kaggle/input/all unlabeled/oral_normal_3519.jpg
# /kaggle/input/all unlabeled/oral_scc_0401.jpg
# /kaggle/input/all unlabeled/oral_scc_0356.jpg
# /kaggle/input/all unlabeled/oral_scc_1294.jpg
# /kaggle/input/all unlabeled/oral_normal_0848.jpg
# /kaggle/input/all unlabeled/oral_scc_0700.jpg
# /kaggle/input/all unlabeled/oral_normal_2357.jpg
# /kaggle/input/all unlabeled/oral_normal_4345.jpg
# /kaggle/input/all unlabeled/oral_scc_3451.jpg
# /kaggle/input/all unlabeled/oral_scc_4619.jpg
# /kaggle/input/all unlabeled/oral_normal_2130.jpg
# /kaggle/input/all unlabeled/oral_normal_3029.jpg
# /kaggle/input/all unlabeled/oral_normal_2864.jpg
# /kaggle/input/all unlabeled/oral_normal_4817.jpg
# /kaggle/input/all unlabeled/oral_normal_3586.jpg
# /kaggle/input/all unlabeled/oral_scc_3574.jpg
# /kaggle/input/all unlabeled/oral_scc_2616.jpg
# /kaggle/input/all unlabeled/oral_scc_4561.jpg
# /kaggle/input/all unlabeled/oral_scc_1249.jpg
# /kaggle/input/all unlabeled/oral_scc_1586.jpg
# /kaggle/input/all unlabeled/oral_normal_0900.jpg
# /kaggle/input/all unlabeled/oral_scc_3636.jpg
# /kaggle/input/all unlabeled/oral_scc_1076.jpg
# /kaggle/input/all unlabeled/oral_scc_0819.jpg
# /kaggle/input/all unlabeled/oral_scc_1727.jpg
# /kaggle/input/all unlabeled/oral_normal_2896.jpg
# /kaggle/input/all unlabeled/oral_scc_2190.jpg
# /kaggle/input/all unlabeled/oral_normal_1553.jpg
# /kaggle/input/all unlabeled/oral_normal_1868.jpg
# /kaggle/input/all unlabeled/oral_scc_0460.jpg
# /kaggle/input/all unlabeled/oral_scc_2713.jpg
# /kaggle/input/all unlabeled/oral_scc_3585.jpg
# /kaggle/input/all unlabeled/oral_scc_1424.jpg
# /kaggle/input/all unlabeled/oral_normal_2200.jpg
# /kaggle/input/all unlabeled/oral_scc_0098.jpg
# /kaggle/input/all unlabeled/oral_scc_2204.jpg
# /kaggle/input/all unlabeled/oral_normal_0044.jpg
# /kaggle/input/all unlabeled/oral_normal_1802.jpg
# /kaggle/input/all unlabeled/oral_scc_2779.jpg
# /kaggle/input/all unlabeled/oral_scc_2672.jpg
# /kaggle/input/all unlabeled/oral_scc_0158.jpg
# /kaggle/input/all unlabeled/oral_normal_1859.jpg
# /kaggle/input/all unlabeled/oral_scc_1706.jpg
# /kaggle/input/all unlabeled/oral_scc_2959.jpg
# /kaggle/input/all unlabeled/oral_normal_1023.jpg
# /kaggle/input/all unlabeled/oral_scc_1223.jpg
# /kaggle/input/all unlabeled/oral_scc_0010.jpg
# /kaggle/input/all unlabeled/oral_scc_0354.jpg
# /kaggle/input/all unlabeled/oral_normal_4363.jpg
# /kaggle/input/all unlabeled/oral_normal_4270.jpg
# /kaggle/input/all unlabeled/oral_normal_3978.jpg
# /kaggle/input/all unlabeled/oral_scc_4803.jpg
# /kaggle/input/all unlabeled/oral_scc_0056.jpg
# /kaggle/input/all unlabeled/oral_normal_2677.jpg
# /kaggle/input/all unlabeled/oral_scc_2633.jpg
# /kaggle/input/all unlabeled/oral_scc_3140.jpg
# /kaggle/input/all unlabeled/oral_normal_1403.jpg
# /kaggle/input/all unlabeled/oral_normal_2314.jpg
# /kaggle/input/all unlabeled/oral_scc_0061.jpg
# /kaggle/input/all unlabeled/oral_scc_0947.jpg
# /kaggle/input/all unlabeled/oral_normal_3424.jpg
# /kaggle/input/all unlabeled/oral_normal_1801.jpg
# /kaggle/input/all unlabeled/oral_scc_4570.jpg
# /kaggle/input/all unlabeled/oral_normal_2972.jpg
# /kaggle/input/all unlabeled/oral_normal_2919.jpg
# /kaggle/input/all unlabeled/oral_scc_3118.jpg
# /kaggle/input/all unlabeled/oral_scc_4998.jpg
# /kaggle/input/all unlabeled/oral_scc_0568.jpg
# /kaggle/input/all unlabeled/oral_scc_3901.jpg
# /kaggle/input/all unlabeled/oral_scc_4675.jpg
# /kaggle/input/all unlabeled/oral_normal_2149.jpg
# /kaggle/input/all unlabeled/oral_scc_4813.jpg
# /kaggle/input/all unlabeled/oral_normal_1759.jpg
# /kaggle/input/all unlabeled/oral_normal_3037.jpg
# /kaggle/input/all unlabeled/oral_scc_2142.jpg
# /kaggle/input/all unlabeled/oral_scc_0236.jpg
# /kaggle/input/all unlabeled/oral_scc_1845.jpg
# /kaggle/input/all unlabeled/oral_normal_4232.jpg
# /kaggle/input/all unlabeled/oral_scc_2016.jpg
# /kaggle/input/all unlabeled/oral_normal_0776.jpg
# /kaggle/input/all unlabeled/oral_normal_4597.jpg
# /kaggle/input/all unlabeled/oral_normal_2408.jpg
# /kaggle/input/all unlabeled/oral_scc_3150.jpg
# /kaggle/input/all unlabeled/oral_scc_4580.jpg
# /kaggle/input/all unlabeled/oral_scc_1449.jpg
# /kaggle/input/all unlabeled/oral_normal_0236.jpg
# /kaggle/input/all unlabeled/oral_normal_2752.jpg
# /kaggle/input/all unlabeled/oral_scc_2896.jpg
# /kaggle/input/all unlabeled/oral_scc_3201.jpg
# /kaggle/input/all unlabeled/oral_scc_0941.jpg
# /kaggle/input/all unlabeled/oral_normal_2941.jpg
# /kaggle/input/all unlabeled/oral_scc_1999.jpg
# /kaggle/input/all unlabeled/oral_scc_4423.jpg
# /kaggle/input/all unlabeled/oral_normal_3827.jpg
# /kaggle/input/all unlabeled/oral_normal_1136.jpg
# /kaggle/input/all unlabeled/oral_scc_4294.jpg
# /kaggle/input/all unlabeled/oral_scc_1209.jpg
# /kaggle/input/all unlabeled/oral_scc_2083.jpg
# /kaggle/input/all unlabeled/oral_scc_1381.jpg
# /kaggle/input/all unlabeled/oral_normal_4643.jpg
# /kaggle/input/all unlabeled/oral_normal_1374.jpg
# /kaggle/input/all unlabeled/oral_scc_4467.jpg
# /kaggle/input/all unlabeled/oral_normal_4793.jpg
# /kaggle/input/all unlabeled/oral_scc_0062.jpg
# /kaggle/input/all unlabeled/oral_scc_2107.jpg
# /kaggle/input/all unlabeled/oral_normal_4342.jpg
# /kaggle/input/all unlabeled/oral_normal_0037.jpg
# /kaggle/input/all unlabeled/oral_normal_2139.jpg
# /kaggle/input/all unlabeled/oral_scc_3095.jpg
# /kaggle/input/all unlabeled/oral_normal_1138.jpg
# /kaggle/input/all unlabeled/oral_normal_3752.jpg
# /kaggle/input/all unlabeled/oral_scc_0783.jpg
# /kaggle/input/all unlabeled/oral_scc_3879.jpg
# /kaggle/input/all unlabeled/oral_normal_2066.jpg
# /kaggle/input/all unlabeled/oral_normal_1209.jpg
# /kaggle/input/all unlabeled/oral_scc_3629.jpg
# /kaggle/input/all unlabeled/oral_normal_4989.jpg
# /kaggle/input/all unlabeled/oral_normal_2338.jpg
# /kaggle/input/all unlabeled/oral_scc_0501.jpg
# /kaggle/input/all unlabeled/oral_scc_1302.jpg
# /kaggle/input/all unlabeled/oral_normal_0736.jpg
# /kaggle/input/all unlabeled/oral_normal_2343.jpg
# /kaggle/input/all unlabeled/oral_scc_0838.jpg
# /kaggle/input/all unlabeled/oral_scc_2420.jpg
# /kaggle/input/all unlabeled/oral_normal_3108.jpg
# /kaggle/input/all unlabeled/oral_scc_2398.jpg
# /kaggle/input/all unlabeled/oral_normal_0543.jpg
# /kaggle/input/all unlabeled/oral_normal_0176.jpg
# /kaggle/input/all unlabeled/oral_normal_1044.jpg
# /kaggle/input/all unlabeled/oral_scc_1102.jpg
# /kaggle/input/all unlabeled/oral_scc_3878.jpg
# /kaggle/input/all unlabeled/oral_scc_0149.jpg
# /kaggle/input/all unlabeled/oral_scc_0384.jpg
# /kaggle/input/all unlabeled/oral_normal_0560.jpg
# /kaggle/input/all unlabeled/oral_scc_1689.jpg
# /kaggle/input/all unlabeled/oral_scc_3511.jpg
# /kaggle/input/all unlabeled/oral_normal_2279.jpg
# /kaggle/input/all unlabeled/oral_scc_1087.jpg
# /kaggle/input/all unlabeled/oral_normal_0256.jpg
# /kaggle/input/all unlabeled/oral_scc_3496.jpg
# /kaggle/input/all unlabeled/oral_scc_2038.jpg
# /kaggle/input/all unlabeled/oral_scc_1807.jpg
# /kaggle/input/all unlabeled/oral_normal_0981.jpg
# /kaggle/input/all unlabeled/oral_scc_4103.jpg
# /kaggle/input/all unlabeled/oral_scc_4352.jpg
# /kaggle/input/all unlabeled/oral_scc_4963.jpg
# /kaggle/input/all unlabeled/oral_normal_2038.jpg
# /kaggle/input/all unlabeled/oral_normal_1006.jpg
# /kaggle/input/all unlabeled/oral_normal_4230.jpg
# /kaggle/input/all unlabeled/oral_normal_1401.jpg
# /kaggle/input/all unlabeled/oral_scc_4454.jpg
# /kaggle/input/all unlabeled/oral_normal_1170.jpg
# /kaggle/input/all unlabeled/oral_scc_0656.jpg
# /kaggle/input/all unlabeled/oral_normal_4893.jpg
# /kaggle/input/all unlabeled/oral_scc_4683.jpg
# /kaggle/input/all unlabeled/oral_scc_2853.jpg
# /kaggle/input/all unlabeled/oral_normal_1690.jpg
# /kaggle/input/all unlabeled/oral_normal_4415.jpg
# /kaggle/input/all unlabeled/oral_normal_1833.jpg
# /kaggle/input/all unlabeled/oral_scc_3583.jpg
# /kaggle/input/all unlabeled/oral_normal_2898.jpg
# /kaggle/input/all unlabeled/oral_scc_1707.jpg
# /kaggle/input/all unlabeled/oral_normal_4199.jpg
# /kaggle/input/all unlabeled/oral_normal_4726.jpg
# /kaggle/input/all unlabeled/oral_scc_0971.jpg
# /kaggle/input/all unlabeled/oral_scc_4695.jpg
# /kaggle/input/all unlabeled/oral_normal_0634.jpg
# /kaggle/input/all unlabeled/oral_normal_2247.jpg
# /kaggle/input/all unlabeled/oral_scc_4700.jpg
# /kaggle/input/all unlabeled/oral_scc_2804.jpg
# /kaggle/input/all unlabeled/oral_normal_0437.jpg
# /kaggle/input/all unlabeled/oral_normal_1066.jpg
# /kaggle/input/all unlabeled/oral_normal_4166.jpg
# /kaggle/input/all unlabeled/oral_scc_2454.jpg
# /kaggle/input/all unlabeled/oral_scc_1663.jpg
# /kaggle/input/all unlabeled/oral_normal_4447.jpg
# /kaggle/input/all unlabeled/oral_scc_1833.jpg
# /kaggle/input/all unlabeled/oral_scc_0300.jpg
# /kaggle/input/all unlabeled/oral_normal_3804.jpg
# /kaggle/input/all unlabeled/oral_normal_2029.jpg
# /kaggle/input/all unlabeled/oral_normal_2318.jpg
# /kaggle/input/all unlabeled/oral_normal_0098.jpg
# /kaggle/input/all unlabeled/oral_scc_0988.jpg
# /kaggle/input/all unlabeled/oral_normal_2904.jpg
# /kaggle/input/all unlabeled/oral_normal_4132.jpg
# /kaggle/input/all unlabeled/oral_scc_2394.jpg
# /kaggle/input/all unlabeled/oral_normal_3672.jpg
# /kaggle/input/all unlabeled/oral_scc_1356.jpg
# /kaggle/input/all unlabeled/oral_normal_0707.jpg
# /kaggle/input/all unlabeled/oral_normal_0160.jpg
# /kaggle/input/all unlabeled/oral_normal_1796.jpg
# /kaggle/input/all unlabeled/oral_scc_4562.jpg
# /kaggle/input/all unlabeled/oral_normal_1982.jpg
# /kaggle/input/all unlabeled/oral_normal_4730.jpg
# /kaggle/input/all unlabeled/oral_normal_0337.jpg
# /kaggle/input/all unlabeled/oral_scc_3376.jpg
# /kaggle/input/all unlabeled/oral_scc_3695.jpg
# /kaggle/input/all unlabeled/oral_scc_0729.jpg
# /kaggle/input/all unlabeled/oral_normal_4830.jpg
# /kaggle/input/all unlabeled/oral_scc_4045.jpg
# /kaggle/input/all unlabeled/oral_normal_1776.jpg
# /kaggle/input/all unlabeled/oral_normal_3368.jpg
# /kaggle/input/all unlabeled/oral_scc_0129.jpg
# /kaggle/input/all unlabeled/oral_normal_2601.jpg
# /kaggle/input/all unlabeled/oral_normal_0274.jpg
# /kaggle/input/all unlabeled/oral_normal_3306.jpg
# /kaggle/input/all unlabeled/oral_scc_2327.jpg
# /kaggle/input/all unlabeled/oral_normal_3277.jpg
# /kaggle/input/all unlabeled/oral_scc_0638.jpg
# /kaggle/input/all unlabeled/oral_normal_2049.jpg
# /kaggle/input/all unlabeled/oral_normal_2724.jpg
# /kaggle/input/all unlabeled/oral_scc_0793.jpg
# /kaggle/input/all unlabeled/oral_scc_0713.jpg
# /kaggle/input/all unlabeled/oral_scc_0701.jpg
# /kaggle/input/all unlabeled/oral_normal_2308.jpg
# /kaggle/input/all unlabeled/oral_scc_1986.jpg
# /kaggle/input/all unlabeled/oral_normal_3923.jpg
# /kaggle/input/all unlabeled/oral_normal_1533.jpg
# /kaggle/input/all unlabeled/oral_scc_1839.jpg
# /kaggle/input/all unlabeled/oral_normal_0853.jpg
# /kaggle/input/all unlabeled/oral_scc_4973.jpg
# /kaggle/input/all unlabeled/oral_normal_0070.jpg
# /kaggle/input/all unlabeled/oral_normal_0119.jpg
# /kaggle/input/all unlabeled/oral_scc_0970.jpg
# /kaggle/input/all unlabeled/oral_scc_3443.jpg
# /kaggle/input/all unlabeled/oral_scc_1617.jpg
# /kaggle/input/all unlabeled/oral_normal_1579.jpg
# /kaggle/input/all unlabeled/oral_normal_3531.jpg
# /kaggle/input/all unlabeled/oral_scc_1558.jpg
# /kaggle/input/all unlabeled/oral_normal_4281.jpg
# /kaggle/input/all unlabeled/oral_normal_2650.jpg
# /kaggle/input/all unlabeled/oral_scc_2130.jpg
# /kaggle/input/all unlabeled/oral_scc_3531.jpg
# /kaggle/input/all unlabeled/oral_scc_0083.jpg
# /kaggle/input/all unlabeled/oral_normal_4131.jpg
# /kaggle/input/all unlabeled/oral_normal_0020.jpg
# /kaggle/input/all unlabeled/oral_normal_3172.jpg
# /kaggle/input/all unlabeled/oral_normal_4172.jpg
# /kaggle/input/all unlabeled/oral_scc_4304.jpg
# /kaggle/input/all unlabeled/oral_scc_4873.jpg
# /kaggle/input/all unlabeled/oral_normal_3527.jpg
# /kaggle/input/all unlabeled/oral_scc_3122.jpg
# /kaggle/input/all unlabeled/oral_scc_1612.jpg
# /kaggle/input/all unlabeled/oral_normal_1358.jpg
# /kaggle/input/all unlabeled/oral_normal_0809.jpg
# /kaggle/input/all unlabeled/oral_scc_2191.jpg
# /kaggle/input/all unlabeled/oral_normal_4683.jpg
# /kaggle/input/all unlabeled/oral_scc_2298.jpg
# /kaggle/input/all unlabeled/oral_normal_4878.jpg
# /kaggle/input/all unlabeled/oral_normal_2973.jpg
# /kaggle/input/all unlabeled/oral_normal_0795.jpg
# /kaggle/input/all unlabeled/oral_normal_1500.jpg
# /kaggle/input/all unlabeled/oral_scc_3529.jpg
# /kaggle/input/all unlabeled/oral_scc_0950.jpg
# /kaggle/input/all unlabeled/oral_normal_1489.jpg
# /kaggle/input/all unlabeled/oral_scc_1165.jpg
# /kaggle/input/all unlabeled/oral_scc_0403.jpg
# /kaggle/input/all unlabeled/oral_scc_1155.jpg
# /kaggle/input/all unlabeled/oral_scc_1429.jpg
# /kaggle/input/all unlabeled/oral_scc_1137.jpg
# /kaggle/input/all unlabeled/oral_scc_0188.jpg
# /kaggle/input/all unlabeled/oral_normal_2917.jpg
# /kaggle/input/all unlabeled/oral_scc_1800.jpg
# /kaggle/input/all unlabeled/oral_normal_2607.jpg
# /kaggle/input/all unlabeled/oral_scc_4074.jpg
# /kaggle/input/all unlabeled/oral_scc_0096.jpg
# /kaggle/input/all unlabeled/oral_scc_0004.jpg
# /kaggle/input/all unlabeled/oral_scc_1919.jpg
# /kaggle/input/all unlabeled/oral_scc_1992.jpg
# /kaggle/input/all unlabeled/oral_scc_3589.jpg
# /kaggle/input/all unlabeled/oral_scc_0393.jpg
# /kaggle/input/all unlabeled/oral_scc_0519.jpg
# /kaggle/input/all unlabeled/oral_normal_2384.jpg
# /kaggle/input/all unlabeled/oral_scc_2341.jpg
# /kaggle/input/all unlabeled/oral_scc_2922.jpg
# /kaggle/input/all unlabeled/oral_scc_0454.jpg
# /kaggle/input/all unlabeled/oral_normal_0535.jpg
# /kaggle/input/all unlabeled/oral_scc_0084.jpg
# /kaggle/input/all unlabeled/oral_normal_1339.jpg
# /kaggle/input/all unlabeled/oral_scc_2565.jpg
# /kaggle/input/all unlabeled/oral_normal_3113.jpg
# /kaggle/input/all unlabeled/oral_normal_1219.jpg
# /kaggle/input/all unlabeled/oral_normal_1100.jpg
# /kaggle/input/all unlabeled/oral_scc_4859.jpg
# /kaggle/input/all unlabeled/oral_normal_4775.jpg
# /kaggle/input/all unlabeled/oral_scc_0123.jpg
# /kaggle/input/all unlabeled/oral_scc_1328.jpg
# /kaggle/input/all unlabeled/oral_normal_3545.jpg
# /kaggle/input/all unlabeled/oral_scc_2737.jpg
# /kaggle/input/all unlabeled/oral_normal_1519.jpg
# /kaggle/input/all unlabeled/oral_scc_4428.jpg
# /kaggle/input/all unlabeled/oral_scc_3398.jpg
# /kaggle/input/all unlabeled/oral_scc_1600.jpg
# /kaggle/input/all unlabeled/oral_scc_0586.jpg
# /kaggle/input/all unlabeled/oral_normal_0698.jpg
# /kaggle/input/all unlabeled/oral_scc_2939.jpg
# /kaggle/input/all unlabeled/oral_scc_3748.jpg
# /kaggle/input/all unlabeled/oral_scc_1435.jpg
# /kaggle/input/all unlabeled/oral_normal_1080.jpg
# /kaggle/input/all unlabeled/oral_normal_1534.jpg
# /kaggle/input/all unlabeled/oral_scc_3422.jpg
# /kaggle/input/all unlabeled/oral_scc_4416.jpg
# /kaggle/input/all unlabeled/oral_scc_4047.jpg
# /kaggle/input/all unlabeled/oral_scc_3401.jpg
# /kaggle/input/all unlabeled/oral_normal_4557.jpg
# /kaggle/input/all unlabeled/oral_normal_0956.jpg
# /kaggle/input/all unlabeled/oral_normal_4278.jpg
# /kaggle/input/all unlabeled/oral_scc_3983.jpg
# /kaggle/input/all unlabeled/oral_normal_1674.jpg
# /kaggle/input/all unlabeled/oral_normal_0137.jpg
# /kaggle/input/all unlabeled/oral_normal_1858.jpg
# /kaggle/input/all unlabeled/oral_scc_4506.jpg
# /kaggle/input/all unlabeled/oral_normal_2136.jpg
# /kaggle/input/all unlabeled/oral_normal_0448.jpg
# /kaggle/input/all unlabeled/oral_scc_0283.jpg
# /kaggle/input/all unlabeled/oral_scc_0360.jpg
# /kaggle/input/all unlabeled/oral_normal_4876.jpg
# /kaggle/input/all unlabeled/oral_scc_0243.jpg
# /kaggle/input/all unlabeled/oral_normal_3861.jpg
# /kaggle/input/all unlabeled/oral_normal_4763.jpg
# /kaggle/input/all unlabeled/oral_scc_4974.jpg
# /kaggle/input/all unlabeled/oral_normal_3610.jpg
# /kaggle/input/all unlabeled/oral_normal_0713.jpg
# /kaggle/input/all unlabeled/oral_scc_4571.jpg
# /kaggle/input/all unlabeled/oral_scc_3308.jpg
# /kaggle/input/all unlabeled/oral_scc_4097.jpg
# /kaggle/input/all unlabeled/oral_normal_4242.jpg
# /kaggle/input/all unlabeled/oral_scc_1122.jpg
# /kaggle/input/all unlabeled/oral_normal_3131.jpg
# /kaggle/input/all unlabeled/oral_scc_3377.jpg
# /kaggle/input/all unlabeled/oral_normal_0531.jpg
# /kaggle/input/all unlabeled/oral_scc_4982.jpg
# /kaggle/input/all unlabeled/oral_scc_2439.jpg
# /kaggle/input/all unlabeled/oral_normal_0695.jpg
# /kaggle/input/all unlabeled/oral_scc_1326.jpg
# /kaggle/input/all unlabeled/oral_scc_2078.jpg
# /kaggle/input/all unlabeled/oral_normal_3115.jpg
# /kaggle/input/all unlabeled/oral_normal_1673.jpg
# /kaggle/input/all unlabeled/oral_normal_1355.jpg
# /kaggle/input/all unlabeled/oral_normal_0614.jpg
# /kaggle/input/all unlabeled/oral_normal_0207.jpg
# /kaggle/input/all unlabeled/oral_scc_0666.jpg
# /kaggle/input/all unlabeled/oral_normal_1640.jpg
# /kaggle/input/all unlabeled/oral_scc_3997.jpg
# /kaggle/input/all unlabeled/oral_scc_2290.jpg
# /kaggle/input/all unlabeled/oral_normal_4865.jpg
# /kaggle/input/all unlabeled/oral_scc_1068.jpg
# /kaggle/input/all unlabeled/oral_scc_2245.jpg
# /kaggle/input/all unlabeled/oral_scc_4606.jpg
# /kaggle/input/all unlabeled/oral_normal_2089.jpg
# /kaggle/input/all unlabeled/oral_scc_3431.jpg
# /kaggle/input/all unlabeled/oral_normal_2603.jpg
# /kaggle/input/all unlabeled/oral_scc_0034.jpg
# /kaggle/input/all unlabeled/oral_normal_0875.jpg
# /kaggle/input/all unlabeled/oral_scc_1484.jpg
# /kaggle/input/all unlabeled/oral_normal_0847.jpg
# /kaggle/input/all unlabeled/oral_scc_4158.jpg
# /kaggle/input/all unlabeled/oral_normal_0316.jpg
# /kaggle/input/all unlabeled/oral_normal_3929.jpg
# /kaggle/input/all unlabeled/oral_scc_2337.jpg
# /kaggle/input/all unlabeled/oral_normal_4868.jpg
# /kaggle/input/all unlabeled/oral_normal_3322.jpg
# /kaggle/input/all unlabeled/oral_normal_3490.jpg
# /kaggle/input/all unlabeled/oral_scc_2378.jpg
# /kaggle/input/all unlabeled/oral_normal_4609.jpg
# /kaggle/input/all unlabeled/oral_normal_2921.jpg
# /kaggle/input/all unlabeled/oral_normal_2355.jpg
# /kaggle/input/all unlabeled/oral_scc_4324.jpg
# /kaggle/input/all unlabeled/oral_normal_4264.jpg
# /kaggle/input/all unlabeled/oral_scc_2294.jpg
# /kaggle/input/all unlabeled/oral_normal_1702.jpg
# /kaggle/input/all unlabeled/oral_normal_3269.jpg
# /kaggle/input/all unlabeled/oral_normal_3052.jpg
# /kaggle/input/all unlabeled/oral_normal_4013.jpg
# /kaggle/input/all unlabeled/oral_scc_0892.jpg
# /kaggle/input/all unlabeled/oral_normal_0590.jpg
# /kaggle/input/all unlabeled/oral_scc_3732.jpg
# /kaggle/input/all unlabeled/oral_normal_3879.jpg
# /kaggle/input/all unlabeled/oral_scc_3105.jpg
# /kaggle/input/all unlabeled/oral_scc_3385.jpg
# /kaggle/input/all unlabeled/oral_scc_0453.jpg
# /kaggle/input/all unlabeled/oral_scc_2238.jpg
# /kaggle/input/all unlabeled/oral_normal_4161.jpg
# /kaggle/input/all unlabeled/oral_scc_0798.jpg
# /kaggle/input/all unlabeled/oral_scc_4259.jpg
# /kaggle/input/all unlabeled/oral_normal_2506.jpg
# /kaggle/input/all unlabeled/oral_normal_2148.jpg
# /kaggle/input/all unlabeled/oral_scc_3580.jpg
# /kaggle/input/all unlabeled/oral_scc_0400.jpg
# /kaggle/input/all unlabeled/oral_scc_3172.jpg
# /kaggle/input/all unlabeled/oral_scc_2972.jpg
# /kaggle/input/all unlabeled/oral_scc_2803.jpg
# /kaggle/input/all unlabeled/oral_scc_0747.jpg
# /kaggle/input/all unlabeled/oral_normal_2131.jpg
# /kaggle/input/all unlabeled/oral_normal_2108.jpg
# /kaggle/input/all unlabeled/oral_scc_0180.jpg
# /kaggle/input/all unlabeled/oral_normal_1184.jpg
# /kaggle/input/all unlabeled/oral_normal_3932.jpg
# /kaggle/input/all unlabeled/oral_scc_3856.jpg
# /kaggle/input/all unlabeled/oral_scc_1577.jpg
# /kaggle/input/all unlabeled/oral_normal_3367.jpg
# /kaggle/input/all unlabeled/oral_scc_1439.jpg
# /kaggle/input/all unlabeled/oral_normal_1344.jpg
# /kaggle/input/all unlabeled/oral_normal_4012.jpg
# /kaggle/input/all unlabeled/oral_normal_2292.jpg
# /kaggle/input/all unlabeled/oral_scc_4935.jpg
# /kaggle/input/all unlabeled/oral_scc_2224.jpg
# /kaggle/input/all unlabeled/oral_normal_3606.jpg
# /kaggle/input/all unlabeled/oral_scc_0320.jpg
# /kaggle/input/all unlabeled/oral_normal_2799.jpg
# /kaggle/input/all unlabeled/oral_normal_2610.jpg
# /kaggle/input/all unlabeled/oral_scc_4959.jpg
# /kaggle/input/all unlabeled/oral_normal_2155.jpg
# /kaggle/input/all unlabeled/oral_normal_3797.jpg
# /kaggle/input/all unlabeled/oral_normal_3642.jpg
# /kaggle/input/all unlabeled/oral_normal_2177.jpg
# /kaggle/input/all unlabeled/oral_scc_2050.jpg
# /kaggle/input/all unlabeled/oral_normal_3145.jpg
# /kaggle/input/all unlabeled/oral_normal_4717.jpg
# /kaggle/input/all unlabeled/oral_scc_3790.jpg
# /kaggle/input/all unlabeled/oral_normal_4942.jpg
# /kaggle/input/all unlabeled/oral_normal_3023.jpg
# /kaggle/input/all unlabeled/oral_normal_3521.jpg
# /kaggle/input/all unlabeled/oral_scc_2025.jpg
# /kaggle/input/all unlabeled/oral_scc_3665.jpg
# /kaggle/input/all unlabeled/oral_scc_1197.jpg
# /kaggle/input/all unlabeled/oral_normal_4024.jpg
# /kaggle/input/all unlabeled/oral_normal_4642.jpg
# /kaggle/input/all unlabeled/oral_scc_4831.jpg
# /kaggle/input/all unlabeled/oral_normal_4658.jpg
# /kaggle/input/all unlabeled/oral_scc_0493.jpg
# /kaggle/input/all unlabeled/oral_normal_3891.jpg
# /kaggle/input/all unlabeled/oral_normal_2346.jpg
# /kaggle/input/all unlabeled/oral_scc_2788.jpg
# /kaggle/input/all unlabeled/oral_normal_0375.jpg
# /kaggle/input/all unlabeled/oral_normal_1975.jpg
# /kaggle/input/all unlabeled/oral_normal_1237.jpg
# /kaggle/input/all unlabeled/oral_normal_4408.jpg
# /kaggle/input/all unlabeled/oral_scc_3647.jpg
# /kaggle/input/all unlabeled/oral_scc_3932.jpg
# /kaggle/input/all unlabeled/oral_scc_0095.jpg
# /kaggle/input/all unlabeled/oral_normal_4361.jpg
# /kaggle/input/all unlabeled/oral_scc_1723.jpg
# /kaggle/input/all unlabeled/oral_normal_3666.jpg
# /kaggle/input/all unlabeled/oral_scc_3749.jpg
# /kaggle/input/all unlabeled/oral_scc_0484.jpg
# /kaggle/input/all unlabeled/oral_scc_1961.jpg
# /kaggle/input/all unlabeled/oral_scc_3791.jpg
# /kaggle/input/all unlabeled/oral_normal_2793.jpg
# /kaggle/input/all unlabeled/oral_scc_0547.jpg
# /kaggle/input/all unlabeled/oral_normal_3387.jpg
# /kaggle/input/all unlabeled/oral_scc_0195.jpg
# /kaggle/input/all unlabeled/oral_scc_3523.jpg
# /kaggle/input/all unlabeled/oral_normal_2784.jpg
# /kaggle/input/all unlabeled/oral_normal_0748.jpg
# /kaggle/input/all unlabeled/oral_scc_4048.jpg
# /kaggle/input/all unlabeled/oral_normal_2221.jpg
# /kaggle/input/all unlabeled/oral_normal_1424.jpg
# /kaggle/input/all unlabeled/oral_normal_3228.jpg
# /kaggle/input/all unlabeled/oral_scc_3466.jpg
# /kaggle/input/all unlabeled/oral_normal_0842.jpg
# /kaggle/input/all unlabeled/oral_scc_3937.jpg
# /kaggle/input/all unlabeled/oral_scc_0898.jpg
# /kaggle/input/all unlabeled/oral_normal_4750.jpg
# /kaggle/input/all unlabeled/oral_scc_0030.jpg
# /kaggle/input/all unlabeled/oral_normal_2718.jpg
# /kaggle/input/all unlabeled/oral_normal_4735.jpg
# /kaggle/input/all unlabeled/oral_scc_0841.jpg
# /kaggle/input/all unlabeled/oral_scc_3759.jpg
# /kaggle/input/all unlabeled/oral_normal_3971.jpg
# /kaggle/input/all unlabeled/oral_scc_3322.jpg
# /kaggle/input/all unlabeled/oral_normal_4839.jpg
# /kaggle/input/all unlabeled/oral_scc_1339.jpg
# /kaggle/input/all unlabeled/oral_scc_2639.jpg
# /kaggle/input/all unlabeled/oral_scc_0285.jpg
# /kaggle/input/all unlabeled/oral_scc_4098.jpg
# /kaggle/input/all unlabeled/oral_normal_0350.jpg
# /kaggle/input/all unlabeled/oral_normal_4364.jpg
# /kaggle/input/all unlabeled/oral_normal_1496.jpg
# /kaggle/input/all unlabeled/oral_scc_3158.jpg
# /kaggle/input/all unlabeled/oral_normal_2406.jpg
# /kaggle/input/all unlabeled/oral_scc_0193.jpg
# /kaggle/input/all unlabeled/oral_scc_1720.jpg
# /kaggle/input/all unlabeled/oral_scc_3303.jpg
# /kaggle/input/all unlabeled/oral_normal_0010.jpg
# /kaggle/input/all unlabeled/oral_scc_2563.jpg
# /kaggle/input/all unlabeled/oral_scc_4844.jpg
# /kaggle/input/all unlabeled/oral_scc_4940.jpg
# /kaggle/input/all unlabeled/oral_normal_1618.jpg
# /kaggle/input/all unlabeled/oral_normal_0158.jpg
# /kaggle/input/all unlabeled/oral_scc_4146.jpg
# /kaggle/input/all unlabeled/oral_scc_4716.jpg
# /kaggle/input/all unlabeled/oral_normal_4892.jpg
# /kaggle/input/all unlabeled/oral_normal_0212.jpg
# /kaggle/input/all unlabeled/oral_normal_1128.jpg
# /kaggle/input/all unlabeled/oral_scc_0597.jpg
# /kaggle/input/all unlabeled/oral_normal_4156.jpg
# /kaggle/input/all unlabeled/oral_normal_1286.jpg
# /kaggle/input/all unlabeled/oral_scc_3091.jpg
# /kaggle/input/all unlabeled/oral_scc_0811.jpg
# /kaggle/input/all unlabeled/oral_scc_0395.jpg
# /kaggle/input/all unlabeled/oral_scc_2524.jpg
# /kaggle/input/all unlabeled/oral_normal_1202.jpg
# /kaggle/input/all unlabeled/oral_scc_4795.jpg
# /kaggle/input/all unlabeled/oral_scc_2167.jpg
# /kaggle/input/all unlabeled/oral_normal_4700.jpg
# /kaggle/input/all unlabeled/oral_normal_2887.jpg
# /kaggle/input/all unlabeled/oral_normal_0099.jpg
# /kaggle/input/all unlabeled/oral_scc_2203.jpg
# /kaggle/input/all unlabeled/oral_scc_1563.jpg
# /kaggle/input/all unlabeled/oral_normal_4685.jpg
# /kaggle/input/all unlabeled/oral_normal_4831.jpg
# /kaggle/input/all unlabeled/oral_normal_3237.jpg
# /kaggle/input/all unlabeled/oral_scc_0189.jpg
# /kaggle/input/all unlabeled/oral_normal_3517.jpg
# /kaggle/input/all unlabeled/oral_normal_0870.jpg
# /kaggle/input/all unlabeled/oral_normal_0355.jpg
# /kaggle/input/all unlabeled/oral_scc_1247.jpg
# /kaggle/input/all unlabeled/oral_normal_1178.jpg
# /kaggle/input/all unlabeled/oral_scc_3746.jpg
# /kaggle/input/all unlabeled/oral_scc_3512.jpg
# /kaggle/input/all unlabeled/oral_scc_2225.jpg
# /kaggle/input/all unlabeled/oral_scc_2506.jpg
# /kaggle/input/all unlabeled/oral_normal_2497.jpg
# /kaggle/input/all unlabeled/oral_scc_0273.jpg
# /kaggle/input/all unlabeled/oral_normal_2176.jpg
# /kaggle/input/all unlabeled/oral_scc_2673.jpg
# /kaggle/input/all unlabeled/oral_normal_3359.jpg
# /kaggle/input/all unlabeled/oral_normal_4033.jpg
# /kaggle/input/all unlabeled/oral_normal_4478.jpg
# /kaggle/input/all unlabeled/oral_normal_2191.jpg
# /kaggle/input/all unlabeled/oral_scc_4432.jpg
# /kaggle/input/all unlabeled/oral_normal_3321.jpg
# /kaggle/input/all unlabeled/oral_scc_4299.jpg
# /kaggle/input/all unlabeled/oral_scc_2861.jpg
# /kaggle/input/all unlabeled/oral_scc_2655.jpg
# /kaggle/input/all unlabeled/oral_scc_1447.jpg
# /kaggle/input/all unlabeled/oral_normal_0984.jpg
# /kaggle/input/all unlabeled/oral_normal_0527.jpg
# /kaggle/input/all unlabeled/oral_scc_2273.jpg
# /kaggle/input/all unlabeled/oral_scc_4870.jpg
# /kaggle/input/all unlabeled/oral_normal_1768.jpg
# /kaggle/input/all unlabeled/oral_normal_1444.jpg
# /kaggle/input/all unlabeled/oral_scc_0913.jpg
# /kaggle/input/all unlabeled/oral_normal_1815.jpg
# /kaggle/input/all unlabeled/oral_normal_2667.jpg
# /kaggle/input/all unlabeled/oral_scc_4992.jpg
# /kaggle/input/all unlabeled/oral_scc_4669.jpg
# /kaggle/input/all unlabeled/oral_normal_0222.jpg
# /kaggle/input/all unlabeled/oral_scc_0919.jpg
# /kaggle/input/all unlabeled/oral_normal_2228.jpg
# /kaggle/input/all unlabeled/oral_scc_1157.jpg
# /kaggle/input/all unlabeled/oral_scc_3012.jpg
# /kaggle/input/all unlabeled/oral_normal_0453.jpg
# /kaggle/input/all unlabeled/oral_normal_2460.jpg
# /kaggle/input/all unlabeled/oral_scc_2893.jpg
# /kaggle/input/all unlabeled/oral_scc_0348.jpg
# /kaggle/input/all unlabeled/oral_normal_0753.jpg
# /kaggle/input/all unlabeled/oral_scc_4635.jpg
# /kaggle/input/all unlabeled/oral_scc_4439.jpg
# /kaggle/input/all unlabeled/oral_normal_2522.jpg
# /kaggle/input/all unlabeled/oral_scc_1371.jpg
# /kaggle/input/all unlabeled/oral_scc_4062.jpg
# /kaggle/input/all unlabeled/oral_normal_3002.jpg
# /kaggle/input/all unlabeled/oral_normal_1146.jpg
# /kaggle/input/all unlabeled/oral_scc_3850.jpg
# /kaggle/input/all unlabeled/oral_normal_2448.jpg
# /kaggle/input/all unlabeled/oral_scc_2092.jpg
# /kaggle/input/all unlabeled/oral_normal_4618.jpg
# /kaggle/input/all unlabeled/oral_normal_2623.jpg
# /kaggle/input/all unlabeled/oral_normal_4383.jpg
# /kaggle/input/all unlabeled/oral_normal_1494.jpg
# /kaggle/input/all unlabeled/oral_scc_1416.jpg
# /kaggle/input/all unlabeled/oral_scc_3889.jpg
# /kaggle/input/all unlabeled/oral_normal_1174.jpg
# /kaggle/input/all unlabeled/oral_normal_4529.jpg
# /kaggle/input/all unlabeled/oral_normal_2820.jpg
# /kaggle/input/all unlabeled/oral_scc_4125.jpg
# /kaggle/input/all unlabeled/oral_scc_3139.jpg
# /kaggle/input/all unlabeled/oral_normal_4694.jpg
# /kaggle/input/all unlabeled/oral_normal_2211.jpg
# /kaggle/input/all unlabeled/oral_normal_2083.jpg
# /kaggle/input/all unlabeled/oral_normal_0326.jpg
# /kaggle/input/all unlabeled/oral_scc_3311.jpg
# /kaggle/input/all unlabeled/oral_scc_1093.jpg
# /kaggle/input/all unlabeled/oral_normal_0757.jpg
# /kaggle/input/all unlabeled/oral_scc_4208.jpg
# /kaggle/input/all unlabeled/oral_scc_2046.jpg
# /kaggle/input/all unlabeled/oral_scc_2792.jpg
# /kaggle/input/all unlabeled/oral_scc_4369.jpg
# /kaggle/input/all unlabeled/oral_scc_3123.jpg
# /kaggle/input/all unlabeled/oral_normal_1914.jpg
# /kaggle/input/all unlabeled/oral_scc_4513.jpg
# /kaggle/input/all unlabeled/oral_scc_4767.jpg
# /kaggle/input/all unlabeled/oral_scc_1287.jpg
# /kaggle/input/all unlabeled/oral_scc_0510.jpg
# /kaggle/input/all unlabeled/oral_scc_1792.jpg
# /kaggle/input/all unlabeled/oral_normal_1608.jpg
# /kaggle/input/all unlabeled/oral_scc_1142.jpg
# /kaggle/input/all unlabeled/oral_scc_2063.jpg
# /kaggle/input/all unlabeled/oral_normal_3651.jpg
# /kaggle/input/all unlabeled/oral_scc_3339.jpg
# /kaggle/input/all unlabeled/oral_normal_0288.jpg
# /kaggle/input/all unlabeled/oral_normal_3862.jpg
# /kaggle/input/all unlabeled/oral_scc_2129.jpg
# /kaggle/input/all unlabeled/oral_normal_3054.jpg
# /kaggle/input/all unlabeled/oral_scc_2255.jpg
# /kaggle/input/all unlabeled/oral_scc_4018.jpg
# /kaggle/input/all unlabeled/oral_scc_0897.jpg
# /kaggle/input/all unlabeled/oral_scc_3741.jpg
# /kaggle/input/all unlabeled/oral_scc_1923.jpg
# /kaggle/input/all unlabeled/oral_scc_2175.jpg
# /kaggle/input/all unlabeled/oral_normal_0388.jpg
# /kaggle/input/all unlabeled/oral_normal_1393.jpg
# ...
# /kaggle/input/all unlabeled/oral_normal_3410.jpg
# /kaggle/input/all unlabeled/oral_scc_0426.jpg
# /kaggle/input/all unlabeled/oral_scc_3361.jpg
# /kaggle/input/all unlabeled/oral_normal_2692.jpg
# /kaggle/input/all unlabeled/oral_normal_1471.jpg
# /kaggle/input/all unlabeled/oral_scc_1838.jpg
# /kaggle/input/all unlabeled/oral_scc_2091.jpg
# /kaggle/input/all unlabeled/oral_scc_4832.jpg
# /kaggle/input/all unlabeled/oral_normal_4440.jpg
# /kaggle/input/all unlabeled/oral_scc_1782.jpg
# /kaggle/input/all unlabeled/oral_normal_0732.jpg
# /kaggle/input/all unlabeled/oral_normal_2064.jpg
# /kaggle/input/all unlabeled/oral_scc_3615.jpg
# /kaggle/input/all unlabeled/oral_normal_3462.jpg
# /kaggle/input/all unlabeled/oral_normal_1228.jpg
# /kaggle/input/all unlabeled/oral_scc_2151.jpg
# /kaggle/input/all unlabeled/oral_normal_3171.jpg
# /kaggle/input/all unlabeled/oral_normal_3349.jpg
# /kaggle/input/all unlabeled/oral_normal_1773.jpg
# /kaggle/input/all unlabeled/oral_scc_3869.jpg
# /kaggle/input/all unlabeled/oral_scc_1011.jpg
# /kaggle/input/all unlabeled/oral_normal_4917.jpg
# /kaggle/input/all unlabeled/oral_normal_0613.jpg
# /kaggle/input/all unlabeled/oral_scc_4442.jpg
# /kaggle/input/all unlabeled/oral_normal_1254.jpg
# /kaggle/input/all unlabeled/oral_scc_3316.jpg
# /kaggle/input/all unlabeled/oral_normal_3777.jpg
# /kaggle/input/all unlabeled/oral_normal_0740.jpg
# /kaggle/input/all unlabeled/oral_scc_3120.jpg
# /kaggle/input/all unlabeled/oral_normal_2955.jpg
# /kaggle/input/all unlabeled/oral_normal_4661.jpg
# /kaggle/input/all unlabeled/oral_scc_4175.jpg
# /kaggle/input/all unlabeled/oral_normal_2511.jpg
# /kaggle/input/all unlabeled/oral_scc_2772.jpg
# /kaggle/input/all unlabeled/oral_normal_4840.jpg
# /kaggle/input/all unlabeled/oral_normal_4955.jpg
# /kaggle/input/all unlabeled/oral_scc_1715.jpg
# /kaggle/input/all unlabeled/oral_scc_3143.jpg
# /kaggle/input/all unlabeled/oral_scc_2785.jpg
# /kaggle/input/all unlabeled/oral_scc_4818.jpg
# /kaggle/input/all unlabeled/oral_scc_2005.jpg
# /kaggle/input/all unlabeled/oral_scc_4134.jpg
# /kaggle/input/all unlabeled/oral_scc_4441.jpg
# /kaggle/input/all unlabeled/oral_normal_0205.jpg
# /kaggle/input/all unlabeled/oral_scc_3622.jpg
# /kaggle/input/all unlabeled/oral_scc_1862.jpg
# /kaggle/input/all unlabeled/oral_normal_3402.jpg
# /kaggle/input/all unlabeled/oral_scc_2626.jpg
# /kaggle/input/all unlabeled/oral_normal_1609.jpg
# /kaggle/input/all unlabeled/oral_normal_2160.jpg
# /kaggle/input/all unlabeled/oral_scc_1791.jpg
# /kaggle/input/all unlabeled/oral_scc_2675.jpg
# /kaggle/input/all unlabeled/oral_scc_3909.jpg
# /kaggle/input/all unlabeled/oral_scc_1002.jpg
# /kaggle/input/all unlabeled/oral_normal_4057.jpg
# /kaggle/input/all unlabeled/oral_normal_4008.jpg
# /kaggle/input/all unlabeled/oral_scc_2845.jpg
# /kaggle/input/all unlabeled/oral_normal_3070.jpg
# /kaggle/input/all unlabeled/oral_normal_2754.jpg
# /kaggle/input/all unlabeled/oral_scc_3199.jpg
# /kaggle/input/all unlabeled/oral_scc_1877.jpg
# /kaggle/input/all unlabeled/oral_normal_4037.jpg
# /kaggle/input/all unlabeled/oral_scc_1656.jpg
# /kaggle/input/all unlabeled/oral_scc_1306.jpg
# /kaggle/input/all unlabeled/oral_scc_4120.jpg
# /kaggle/input/all unlabeled/oral_normal_4781.jpg
# /kaggle/input/all unlabeled/oral_scc_2720.jpg
# /kaggle/input/all unlabeled/oral_normal_3181.jpg
# /kaggle/input/all unlabeled/oral_normal_4783.jpg
# /kaggle/input/all unlabeled/oral_scc_0862.jpg
# /kaggle/input/all unlabeled/oral_normal_0577.jpg
# /kaggle/input/all unlabeled/oral_normal_0493.jpg
# /kaggle/input/all unlabeled/oral_scc_3764.jpg
# /kaggle/input/all unlabeled/oral_scc_1202.jpg
# /kaggle/input/all unlabeled/oral_scc_2364.jpg
# /kaggle/input/all unlabeled/oral_scc_2701.jpg
# /kaggle/input/all unlabeled/oral_normal_0107.jpg
# /kaggle/input/all unlabeled/oral_scc_2949.jpg
# /kaggle/input/all unlabeled/oral_normal_2291.jpg
# /kaggle/input/all unlabeled/oral_normal_0783.jpg
# /kaggle/input/all unlabeled/oral_scc_2649.jpg
# /kaggle/input/all unlabeled/oral_normal_4244.jpg
# /kaggle/input/all unlabeled/oral_normal_2327.jpg
# /kaggle/input/all unlabeled/oral_scc_2440.jpg
# /kaggle/input/all unlabeled/oral_scc_4877.jpg
# /kaggle/input/all unlabeled/oral_normal_4718.jpg
# /kaggle/input/all unlabeled/oral_normal_1014.jpg
# /kaggle/input/all unlabeled/oral_scc_0650.jpg
# /kaggle/input/all unlabeled/oral_normal_1416.jpg
# /kaggle/input/all unlabeled/oral_scc_1759.jpg
# /kaggle/input/all unlabeled/oral_scc_1226.jpg
# /kaggle/input/all unlabeled/oral_scc_2456.jpg
# /kaggle/input/all unlabeled/oral_normal_1715.jpg
# /kaggle/input/all unlabeled/oral_normal_4421.jpg
# /kaggle/input/all unlabeled/oral_normal_2529.jpg
# /kaggle/input/all unlabeled/oral_scc_4262.jpg
# /kaggle/input/all unlabeled/oral_normal_2091.jpg
# /kaggle/input/all unlabeled/oral_scc_2935.jpg
# /kaggle/input/all unlabeled/oral_scc_1162.jpg
# /kaggle/input/all unlabeled/oral_scc_2622.jpg
# /kaggle/input/all unlabeled/oral_scc_1909.jpg
# /kaggle/input/all unlabeled/oral_normal_1696.jpg
# /kaggle/input/all unlabeled/oral_scc_1896.jpg
# /kaggle/input/all unlabeled/oral_scc_4139.jpg
# /kaggle/input/all unlabeled/oral_scc_0407.jpg
# /kaggle/input/all unlabeled/oral_normal_2860.jpg
# /kaggle/input/all unlabeled/oral_normal_3166.jpg
# /kaggle/input/all unlabeled/oral_normal_4500.jpg
# /kaggle/input/all unlabeled/oral_normal_0246.jpg
# /kaggle/input/all unlabeled/oral_scc_1401.jpg
# /kaggle/input/all unlabeled/oral_scc_3468.jpg
# /kaggle/input/all unlabeled/oral_scc_4802.jpg
# /kaggle/input/all unlabeled/oral_normal_2628.jpg
# /kaggle/input/all unlabeled/oral_normal_3740.jpg
# /kaggle/input/all unlabeled/oral_scc_1000.jpg
# /kaggle/input/all unlabeled/oral_normal_0110.jpg
# /kaggle/input/all unlabeled/oral_scc_1993.jpg
# /kaggle/input/all unlabeled/oral_scc_0217.jpg
# /kaggle/input/all unlabeled/oral_normal_3549.jpg
# /kaggle/input/all unlabeled/oral_normal_4996.jpg
# /kaggle/input/all unlabeled/oral_normal_0226.jpg
# /kaggle/input/all unlabeled/oral_normal_3924.jpg
# /kaggle/input/all unlabeled/oral_scc_2443.jpg
# /kaggle/input/all unlabeled/oral_normal_3058.jpg
# /kaggle/input/all unlabeled/oral_normal_2959.jpg
# /kaggle/input/all unlabeled/oral_normal_2824.jpg
# /kaggle/input/all unlabeled/oral_scc_0051.jpg
# /kaggle/input/all unlabeled/oral_scc_3651.jpg
# /kaggle/input/all unlabeled/oral_normal_0454.jpg
# /kaggle/input/all unlabeled/oral_scc_3925.jpg
# /kaggle/input/all unlabeled/oral_scc_2342.jpg
# /kaggle/input/all unlabeled/oral_scc_4863.jpg
# /kaggle/input/all unlabeled/oral_scc_2153.jpg
# /kaggle/input/all unlabeled/oral_normal_4650.jpg
# /kaggle/input/all unlabeled/oral_normal_0972.jpg
# /kaggle/input/all unlabeled/oral_normal_0541.jpg
# /kaggle/input/all unlabeled/oral_normal_1909.jpg
# /kaggle/input/all unlabeled/oral_scc_1913.jpg
# /kaggle/input/all unlabeled/oral_normal_4747.jpg
# /kaggle/input/all unlabeled/oral_scc_3763.jpg
# /kaggle/input/all unlabeled/oral_normal_4987.jpg
# /kaggle/input/all unlabeled/oral_normal_0324.jpg
# /kaggle/input/all unlabeled/oral_normal_0878.jpg
# /kaggle/input/all unlabeled/oral_scc_1960.jpg
# /kaggle/input/all unlabeled/oral_normal_0446.jpg
# /kaggle/input/all unlabeled/oral_scc_2076.jpg
# /kaggle/input/all unlabeled/oral_scc_1350.jpg
# /kaggle/input/all unlabeled/oral_scc_1996.jpg
# /kaggle/input/all unlabeled/oral_normal_3533.jpg
# /kaggle/input/all unlabeled/oral_scc_2049.jpg
# /kaggle/input/all unlabeled/oral_normal_0405.jpg
# /kaggle/input/all unlabeled/oral_scc_3348.jpg
# /kaggle/input/all unlabeled/oral_scc_3510.jpg
# /kaggle/input/all unlabeled/oral_normal_2434.jpg
# /kaggle/input/all unlabeled/oral_normal_0620.jpg
# /kaggle/input/all unlabeled/oral_scc_2283.jpg
# /kaggle/input/all unlabeled/oral_normal_0998.jpg
# /kaggle/input/all unlabeled/oral_scc_2698.jpg
# /kaggle/input/all unlabeled/oral_normal_2715.jpg
# /kaggle/input/all unlabeled/oral_scc_0579.jpg
# /kaggle/input/all unlabeled/oral_normal_4835.jpg
# /kaggle/input/all unlabeled/oral_normal_2077.jpg
# /kaggle/input/all unlabeled/oral_normal_2500.jpg
# /kaggle/input/all unlabeled/oral_normal_1353.jpg
# /kaggle/input/all unlabeled/oral_scc_2037.jpg
# /kaggle/input/all unlabeled/oral_normal_2496.jpg
# /kaggle/input/all unlabeled/oral_normal_0409.jpg
# /kaggle/input/all unlabeled/oral_scc_4482.jpg
# /kaggle/input/all unlabeled/oral_normal_0397.jpg
# /kaggle/input/all unlabeled/oral_scc_2171.jpg
# /kaggle/input/all unlabeled/oral_normal_3869.jpg
# /kaggle/input/all unlabeled/oral_normal_2807.jpg
# /kaggle/input/all unlabeled/oral_scc_1420.jpg
# /kaggle/input/all unlabeled/oral_normal_0170.jpg
# /kaggle/input/all unlabeled/oral_normal_4678.jpg
# /kaggle/input/all unlabeled/oral_scc_2735.jpg
# /kaggle/input/all unlabeled/oral_normal_1646.jpg
# /kaggle/input/all unlabeled/oral_normal_4202.jpg
# /kaggle/input/all unlabeled/oral_normal_3395.jpg
# /kaggle/input/all unlabeled/oral_normal_4786.jpg
# /kaggle/input/all unlabeled/oral_normal_4004.jpg
# /kaggle/input/all unlabeled/oral_normal_1555.jpg
# /kaggle/input/all unlabeled/oral_normal_2087.jpg
# /kaggle/input/all unlabeled/oral_normal_1474.jpg
# /kaggle/input/all unlabeled/oral_normal_0911.jpg
# /kaggle/input/all unlabeled/oral_normal_1548.jpg
# /kaggle/input/all unlabeled/oral_normal_1543.jpg
# /kaggle/input/all unlabeled/oral_scc_4491.jpg
# /kaggle/input/all unlabeled/oral_scc_3137.jpg
# /kaggle/input/all unlabeled/oral_scc_3920.jpg
# /kaggle/input/all unlabeled/oral_scc_2158.jpg
# /kaggle/input/all unlabeled/oral_scc_2047.jpg
# /kaggle/input/all unlabeled/oral_normal_3117.jpg
# /kaggle/input/all unlabeled/oral_normal_0055.jpg
# /kaggle/input/all unlabeled/oral_normal_2983.jpg
# /kaggle/input/all unlabeled/oral_normal_4282.jpg
# /kaggle/input/all unlabeled/oral_scc_3025.jpg
# /kaggle/input/all unlabeled/oral_normal_4501.jpg
# /kaggle/input/all unlabeled/oral_normal_3222.jpg
# /kaggle/input/all unlabeled/oral_normal_2456.jpg
# /kaggle/input/all unlabeled/oral_scc_2765.jpg
# /kaggle/input/all unlabeled/oral_normal_1693.jpg
# /kaggle/input/all unlabeled/oral_normal_1560.jpg
# /kaggle/input/all unlabeled/oral_normal_1085.jpg
# /kaggle/input/all unlabeled/oral_scc_1393.jpg
# /kaggle/input/all unlabeled/oral_normal_4767.jpg
# /kaggle/input/all unlabeled/oral_normal_3750.jpg
# /kaggle/input/all unlabeled/oral_normal_1449.jpg
# /kaggle/input/all unlabeled/oral_normal_3902.jpg
# /kaggle/input/all unlabeled/oral_scc_1638.jpg
# /kaggle/input/all unlabeled/oral_scc_4357.jpg
# /kaggle/input/all unlabeled/oral_scc_2916.jpg
# /kaggle/input/all unlabeled/oral_normal_0771.jpg
# /kaggle/input/all unlabeled/oral_normal_3612.jpg
# /kaggle/input/all unlabeled/oral_normal_2322.jpg
# /kaggle/input/all unlabeled/oral_scc_2805.jpg
# /kaggle/input/all unlabeled/oral_scc_2497.jpg
# /kaggle/input/all unlabeled/oral_normal_1665.jpg
# /kaggle/input/all unlabeled/oral_scc_2491.jpg
# /kaggle/input/all unlabeled/oral_normal_4373.jpg
# /kaggle/input/all unlabeled/oral_normal_1106.jpg
# /kaggle/input/all unlabeled/oral_normal_4171.jpg
# /kaggle/input/all unlabeled/oral_normal_1225.jpg
# /kaggle/input/all unlabeled/oral_normal_0817.jpg
# /kaggle/input/all unlabeled/oral_scc_1296.jpg
# /kaggle/input/all unlabeled/oral_normal_2150.jpg
# /kaggle/input/all unlabeled/oral_scc_4966.jpg
# /kaggle/input/all unlabeled/oral_scc_4662.jpg
# /kaggle/input/all unlabeled/oral_scc_0100.jpg
# /kaggle/input/all unlabeled/oral_scc_2950.jpg
# /kaggle/input/all unlabeled/oral_normal_0384.jpg
# /kaggle/input/all unlabeled/oral_normal_1981.jpg
# /kaggle/input/all unlabeled/oral_normal_0130.jpg
# /kaggle/input/all unlabeled/oral_scc_1206.jpg
# /kaggle/input/all unlabeled/oral_normal_1873.jpg
# /kaggle/input/all unlabeled/oral_normal_1920.jpg
# /kaggle/input/all unlabeled/oral_normal_2758.jpg
# /kaggle/input/all unlabeled/oral_scc_2219.jpg
# /kaggle/input/all unlabeled/oral_scc_3252.jpg
# /kaggle/input/all unlabeled/oral_scc_1143.jpg
# /kaggle/input/all unlabeled/oral_scc_4002.jpg
# /kaggle/input/all unlabeled/oral_scc_1846.jpg
# /kaggle/input/all unlabeled/oral_scc_4911.jpg
# /kaggle/input/all unlabeled/oral_normal_3805.jpg
# /kaggle/input/all unlabeled/oral_scc_3848.jpg
# /kaggle/input/all unlabeled/oral_normal_1027.jpg
# /kaggle/input/all unlabeled/oral_scc_2061.jpg
# /kaggle/input/all unlabeled/oral_scc_0060.jpg
# /kaggle/input/all unlabeled/oral_normal_4891.jpg
# /kaggle/input/all unlabeled/oral_scc_0689.jpg
# /kaggle/input/all unlabeled/oral_normal_2966.jpg
# /kaggle/input/all unlabeled/oral_scc_4594.jpg
# /kaggle/input/all unlabeled/oral_scc_3069.jpg
# /kaggle/input/all unlabeled/oral_normal_3835.jpg
# /kaggle/input/all unlabeled/oral_scc_4922.jpg
# /kaggle/input/all unlabeled/oral_normal_0173.jpg
# /kaggle/input/all unlabeled/oral_scc_1417.jpg
# /kaggle/input/all unlabeled/oral_scc_3834.jpg
# /kaggle/input/all unlabeled/oral_scc_4740.jpg
# /kaggle/input/all unlabeled/oral_normal_4776.jpg
# /kaggle/input/all unlabeled/oral_normal_0575.jpg
# /kaggle/input/all unlabeled/oral_normal_2071.jpg
# /kaggle/input/all unlabeled/oral_scc_0614.jpg
# /kaggle/input/all unlabeled/oral_scc_0765.jpg
# /kaggle/input/all unlabeled/oral_scc_3307.jpg
# /kaggle/input/all unlabeled/oral_scc_2449.jpg
# /kaggle/input/all unlabeled/oral_normal_3664.jpg
# /kaggle/input/all unlabeled/oral_scc_3449.jpg
# /kaggle/input/all unlabeled/oral_scc_3096.jpg
# /kaggle/input/all unlabeled/oral_normal_0278.jpg
# /kaggle/input/all unlabeled/oral_scc_0410.jpg
# /kaggle/input/all unlabeled/oral_normal_0915.jpg
# /kaggle/input/all unlabeled/oral_scc_2475.jpg
# /kaggle/input/all unlabeled/oral_scc_4646.jpg
# /kaggle/input/all unlabeled/oral_scc_2131.jpg
# /kaggle/input/all unlabeled/oral_normal_2345.jpg
# /kaggle/input/all unlabeled/oral_scc_1154.jpg
# /kaggle/input/all unlabeled/oral_scc_3302.jpg
# /kaggle/input/all unlabeled/oral_scc_3470.jpg
# /kaggle/input/all unlabeled/oral_normal_3947.jpg
# /kaggle/input/all unlabeled/oral_normal_1913.jpg
# /kaggle/input/all unlabeled/oral_scc_0323.jpg
# /kaggle/input/all unlabeled/oral_scc_4475.jpg
# /kaggle/input/all unlabeled/oral_scc_3801.jpg
# /kaggle/input/all unlabeled/oral_scc_4013.jpg
# /kaggle/input/all unlabeled/oral_scc_0917.jpg
# /kaggle/input/all unlabeled/oral_scc_0271.jpg
# /kaggle/input/all unlabeled/oral_scc_2357.jpg
# /kaggle/input/all unlabeled/oral_scc_2826.jpg
# /kaggle/input/all unlabeled/oral_normal_2861.jpg
# /kaggle/input/all unlabeled/oral_scc_2668.jpg
# /kaggle/input/all unlabeled/oral_scc_4188.jpg
# /kaggle/input/all unlabeled/oral_scc_0306.jpg
# /kaggle/input/all unlabeled/oral_scc_1263.jpg
# /kaggle/input/all unlabeled/oral_scc_4095.jpg
# /kaggle/input/all unlabeled/oral_scc_4067.jpg
# /kaggle/input/all unlabeled/oral_normal_1451.jpg
# /kaggle/input/all unlabeled/oral_scc_1991.jpg
# /kaggle/input/all unlabeled/oral_normal_4492.jpg
# /kaggle/input/all unlabeled/oral_normal_1234.jpg
# /kaggle/input/all unlabeled/oral_scc_4806.jpg
# /kaggle/input/all unlabeled/oral_normal_3968.jpg
# /kaggle/input/all unlabeled/oral_scc_3346.jpg
# /kaggle/input/all unlabeled/oral_scc_0007.jpg
# /kaggle/input/all unlabeled/oral_scc_1835.jpg
# /kaggle/input/all unlabeled/oral_scc_1255.jpg
# /kaggle/input/all unlabeled/oral_scc_0683.jpg
# /kaggle/input/all unlabeled/oral_scc_2157.jpg
# /kaggle/input/all unlabeled/oral_normal_3347.jpg
# /kaggle/input/all unlabeled/oral_normal_3203.jpg
# /kaggle/input/all unlabeled/oral_scc_0303.jpg
# /kaggle/input/all unlabeled/oral_scc_0900.jpg
# /kaggle/input/all unlabeled/oral_scc_0964.jpg
# /kaggle/input/all unlabeled/oral_scc_0254.jpg
# /kaggle/input/all unlabeled/oral_scc_4952.jpg
# /kaggle/input/all unlabeled/oral_normal_0741.jpg
# /kaggle/input/all unlabeled/oral_normal_0408.jpg
# /kaggle/input/all unlabeled/oral_normal_1192.jpg
# /kaggle/input/all unlabeled/oral_normal_0884.jpg
# /kaggle/input/all unlabeled/oral_normal_2696.jpg
# /kaggle/input/all unlabeled/oral_scc_1348.jpg
# /kaggle/input/all unlabeled/oral_normal_4915.jpg
# /kaggle/input/all unlabeled/oral_normal_4205.jpg
# /kaggle/input/all unlabeled/oral_scc_0187.jpg
# /kaggle/input/all unlabeled/oral_scc_2206.jpg
# /kaggle/input/all unlabeled/oral_scc_4958.jpg
# /kaggle/input/all unlabeled/oral_normal_4306.jpg
# /kaggle/input/all unlabeled/oral_normal_0683.jpg
# /kaggle/input/all unlabeled/oral_normal_2473.jpg
# /kaggle/input/all unlabeled/oral_normal_1729.jpg
# /kaggle/input/all unlabeled/oral_normal_1149.jpg
# /kaggle/input/all unlabeled/oral_scc_3579.jpg
# /kaggle/input/all unlabeled/oral_scc_0125.jpg
# /kaggle/input/all unlabeled/oral_normal_1709.jpg
# /kaggle/input/all unlabeled/oral_normal_3717.jpg
# /kaggle/input/all unlabeled/oral_scc_4796.jpg

# %%
# !pip install torch torchvision matplotlib numpy tqdm
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy) (2024.2.0)

# %%
! pip install efficientnet_pytorch
# Out:
# Requirement already satisfied: efficientnet_pytorch in /usr/local/lib/python3.11/dist-packages (0.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from efficientnet_pytorch) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->efficientnet_pytorch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->efficientnet_pytorch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->efficientnet_pytorch) (3.0.2)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.manifold import TSNE
from torch.cuda.amp import autocast, GradScaler
import os
import torch.optim as optim
from efficientnet_pytorch import EfficientNet  # pip install efficientnet_pytorch
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
# Set environment to reduce memory fragmentation
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
# Set random seed for reproducibility
torch.manual_seed(42)

# %%
# Custom Dataset for Unlabeled Images (with two augmentations)
class OralCancerDataset(Dataset):
    def __init__(self, image_paths, transform1, transform2):
        self.image_paths = image_paths
        self.transform1 = transform1
        self.transform2 = transform2

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('RGB')
        view1 = self.transform1(image)
        view2 = self.transform2(image)
        return view1, view2

# %%
# Define wrapper for downstream task (single image + label) - Simplified since base uses None transform
class DownstreamWrapper(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __len__(self):
        return len(self.subset)

    def __getitem__(self, idx):
        item = self.subset[idx]
        if len(item) == 3:  # From aug dataset, ignore img2
            img, _, label = item
        else:  # From base (PIL, label)
            img, label = item
        if self.transform:
            img = self.transform(img)
        return img, label

# %%
# Projector MLP
class Projector(nn.Module):
    def __init__(self, in_dim, hidden_dim=2048, out_dim=128):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, out_dim)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Define SimCLR model
class SimCLR(nn.Module):
    def __init__(self, base_encoder, projection_dim=128):
        super(SimCLR, self).__init__()
        self.encoder = base_encoder
        self.encoder.classifier = nn.Identity()  # Remove the final classifier to get 1280 features
        self.feature_dim = 1280  # EfficientNet-B0 feature dim after avgpool
        self.projection_head = nn.Sequential(
            nn.Linear(self.feature_dim, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Linear(512, projection_dim)
        )
    
    def forward(self, x):
        h = self.encoder(x)  # (batch, 1280)
        z = self.projection_head(h)
        return F.normalize(z, dim=1)  # L2 normalization

# %%
# Define NT-Xent loss
def nt_xent_loss(z1, z2, temperature=0.5):
    batch_size = z1.size(0)
    z = torch.cat([z1, z2], dim=0)  # [2N, projection_dim]
    sim_matrix = F.cosine_similarity(z.unsqueeze(1), z.unsqueeze(0), dim=2) / temperature
    # Correct labels for positive pairs
    labels = torch.cat([torch.arange(batch_size, 2 * batch_size), torch.arange(batch_size)]).to(z1.device)
    # Mask self-similarities (diagonal) to -inf
    mask = torch.eye(2 * batch_size, device=z1.device).bool()
    sim_matrix = sim_matrix.masked_fill(mask, -float('inf'))
    loss = F.cross_entropy(sim_matrix, labels)
    return loss

# %%
# Data transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ColorJitter(0.2, 0.2, 0.2, 0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

downstream_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
# Define OralCancerSimCLRDataset (assumed based on usage)
class OralCancerSimCLRDataset(Dataset):
    def __init__(self, data_path, transform=None):
        self.data_path = data_path
        self.transform = transform
        self.image_paths = [os.path.join(data_path, f) for f in os.listdir(data_path) if f.endswith('.jpg')]
        self.labels = [0 if 'normal' in os.path.basename(p) else 1 for p in self.image_paths]  # 0=Non-Cancer, 1=Cancer

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        if self.transform:
            img1 = self.transform(image)
            img2 = self.transform(image) if self.transform else image
            return img1, img2, label
        return image, label

aug_dataset = OralCancerSimCLRDataset(data_path=data_path, transform=transform)  # For pre-training
print(f"Found {len(aug_dataset)} images")
# Out:
# Found 10002 images

# %%
# Load dataset for pre-training (with aug)
data_path = '/kaggle/input/all unlabeled'
if not os.path.exists(data_path):
    raise ValueError(f"Data path {data_path} does not exist. Run '!ls /kaggle/input/' to check.")
print(f"Loading dataset from {data_path}")

aug_dataset = OralCancerSimCLRDataset(data_path=data_path, transform=transform)  # For pre-training
print(f"Found {len(aug_dataset)} images")
# Out:
# Loading dataset from /kaggle/input/all unlabeled
# Found 10002 images

# %%
# Split indices
pretrain_size = int(0.2 * len(aug_dataset))  # ~8001
remaining_size = len(aug_dataset) - pretrain_size  # ~2001
pretrain_split, remaining_split = random_split(aug_dataset, [pretrain_size, remaining_size])
pretrain_indices = pretrain_split.indices
remaining_indices = remaining_split.indices
print(f"Pretrain dataset size: {len(pretrain_indices)}")
print(f"Remaining dataset size: {len(remaining_indices)}")
# Out:
# Pretrain dataset size: 2000
# Remaining dataset size: 8002

# %%
# Pre-training loader (uses aug_dataset subset)
train_loader = DataLoader(pretrain_split, batch_size=32, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)

# %%
# Pre-training loader (uses aug_dataset subset)
train_loader = DataLoader(pretrain_split, batch_size=32, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)

# %%
# Create base dataset without transform (for downstream, t-SNE, test - PIL images)
base_dataset = OralCancerSimCLRDataset(data_path=data_path, transform=None)

# %%
# Downstream dataset (same 80% indices, but from base)
downstream_subset = torch.utils.data.Subset(base_dataset, pretrain_indices)
downstream_dataset = DownstreamWrapper(downstream_subset, downstream_transform)
train_size = int(0.2 * len(downstream_dataset))  # ~5601
val_size = len(downstream_dataset) - train_size  # ~2400
downstream_train_split, downstream_val_split = random_split(downstream_dataset, [train_size, val_size])

# %%
# Downstream loaders
train_loader_downstream = DataLoader(downstream_train_split, batch_size=32, shuffle=True, num_workers=2, pin_memory=True, drop_last=True)
val_loader_downstream = DataLoader(downstream_val_split, batch_size=32, shuffle=False, num_workers=2, pin_memory=True, drop_last=True)

# %%
# Test loader (20% holdout from base)
test_subset = torch.utils.data.Subset(base_dataset, remaining_indices)
test_dataset = DownstreamWrapper(test_subset, downstream_transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2, pin_memory=True, drop_last=True)

# %%
# Initialize SimCLR model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
base_encoder = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)
model = SimCLR(base_encoder).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
scaler = torch.amp.GradScaler(device)

# %%
# Clear GPU cache before training (Fix OOM)
torch.cuda.empty_cache()

# %%
num_epochs = 100
pretrain_losses = []
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    for batch in tqdm(train_loader, desc=f"Pretrain Epoch {epoch+1}/{num_epochs}"):
        img1, img2, _ = batch
        img1, img2 = img1.to(device), img2.to(device)
        optimizer.zero_grad()
        with torch.amp.autocast(device_type='cuda'):  # Fixed for compatibility
            z1 = model(img1)
            z2 = model(img2)
            loss = nt_xent_loss(z1, z2, temperature=0.5)
        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    avg_loss = total_loss / len(train_loader)
    pretrain_losses.append(avg_loss)
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")
    torch.cuda.empty_cache()  # Clear cache after each epoch
# Out:
# Pretrain Epoch 1/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 1, Loss: 3.4801
# Pretrain Epoch 2/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 2, Loss: 2.9794
# Pretrain Epoch 3/100: 100%|██████████| 62/62 [00:25<00:00,  2.47it/s]
# Epoch 3, Loss: 2.7271
# Pretrain Epoch 4/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 4, Loss: 2.5999
# Pretrain Epoch 5/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 5, Loss: 2.5338
# Pretrain Epoch 6/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 6, Loss: 2.4907
# Pretrain Epoch 7/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 7, Loss: 2.4572
# Pretrain Epoch 8/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 8, Loss: 2.4318
# Pretrain Epoch 9/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 9, Loss: 2.4081
# Pretrain Epoch 10/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 10, Loss: 2.3968
# Pretrain Epoch 11/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 11, Loss: 2.3847
# Pretrain Epoch 12/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 12, Loss: 2.3707
# Pretrain Epoch 13/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 13, Loss: 2.3598
# Pretrain Epoch 14/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 14, Loss: 2.3524
# Pretrain Epoch 15/100: 100%|██████████| 62/62 [00:25<00:00,  2.47it/s]
# Epoch 15, Loss: 2.3463
# Pretrain Epoch 16/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 16, Loss: 2.3410
# Pretrain Epoch 17/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 17, Loss: 2.3313
# Pretrain Epoch 18/100: 100%|██████████| 62/62 [00:25<00:00,  2.46it/s]
# Epoch 18, Loss: 2.3302
# Pretrain Epoch 19/100: 100%|██████████| 62/62 [00:24<00:00,  2.57it/s]
# Epoch 19, Loss: 2.3195
# Pretrain Epoch 20/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 20, Loss: 2.3208
# Pretrain Epoch 21/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 21, Loss: 2.3175
# Pretrain Epoch 22/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 22, Loss: 2.3106
# Pretrain Epoch 23/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 23, Loss: 2.3101
# Pretrain Epoch 24/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 24, Loss: 2.3057
# Pretrain Epoch 25/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 25, Loss: 2.3030
# Pretrain Epoch 26/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 26, Loss: 2.2994
# Pretrain Epoch 27/100: 100%|██████████| 62/62 [00:25<00:00,  2.48it/s]
# Epoch 27, Loss: 2.2957
# Pretrain Epoch 28/100: 100%|██████████| 62/62 [00:25<00:00,  2.47it/s]
# Epoch 28, Loss: 2.2956
# Pretrain Epoch 29/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 29, Loss: 2.2931
# Pretrain Epoch 30/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 30, Loss: 2.2899
# Pretrain Epoch 31/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 31, Loss: 2.2895
# Pretrain Epoch 32/100: 100%|██████████| 62/62 [00:24<00:00,  2.55it/s]
# Epoch 32, Loss: 2.2880
# Pretrain Epoch 33/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 33, Loss: 2.2844
# Pretrain Epoch 34/100: 100%|██████████| 62/62 [00:25<00:00,  2.48it/s]
# Epoch 34, Loss: 2.2808
# Pretrain Epoch 35/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 35, Loss: 2.2838
# Pretrain Epoch 36/100: 100%|██████████| 62/62 [00:24<00:00,  2.56it/s]
# Epoch 36, Loss: 2.2831
# Pretrain Epoch 37/100: 100%|██████████| 62/62 [00:25<00:00,  2.48it/s]
# Epoch 37, Loss: 2.2822
# Pretrain Epoch 38/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 38, Loss: 2.2771
# Pretrain Epoch 39/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 39, Loss: 2.2780
# Pretrain Epoch 40/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 40, Loss: 2.2795
# Pretrain Epoch 41/100: 100%|██████████| 62/62 [00:25<00:00,  2.45it/s]
# Epoch 41, Loss: 2.2783
# Pretrain Epoch 42/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 42, Loss: 2.2765
# Pretrain Epoch 43/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 43, Loss: 2.2764
# Pretrain Epoch 44/100: 100%|██████████| 62/62 [00:25<00:00,  2.48it/s]
# Epoch 44, Loss: 2.2738
# Pretrain Epoch 45/100: 100%|██████████| 62/62 [00:25<00:00,  2.44it/s]
# Epoch 45, Loss: 2.2772
# Pretrain Epoch 46/100: 100%|██████████| 62/62 [00:25<00:00,  2.43it/s]
# Epoch 46, Loss: 2.2723
# Pretrain Epoch 47/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 47, Loss: 2.2734
# Pretrain Epoch 48/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 48, Loss: 2.2746
# Pretrain Epoch 49/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 49, Loss: 2.2744
# Pretrain Epoch 50/100: 100%|██████████| 62/62 [00:24<00:00,  2.48it/s]
# Epoch 50, Loss: 2.2680
# Pretrain Epoch 51/100: 100%|██████████| 62/62 [00:25<00:00,  2.48it/s]
# Epoch 51, Loss: 2.2693
# Pretrain Epoch 52/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 52, Loss: 2.2721
# Pretrain Epoch 53/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 53, Loss: 2.2671
# Pretrain Epoch 54/100: 100%|██████████| 62/62 [00:25<00:00,  2.46it/s]
# Epoch 54, Loss: 2.2721
# Pretrain Epoch 55/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 55, Loss: 2.2676
# Pretrain Epoch 56/100: 100%|██████████| 62/62 [00:25<00:00,  2.47it/s]
# Epoch 56, Loss: 2.2677
# Pretrain Epoch 57/100: 100%|██████████| 62/62 [00:25<00:00,  2.46it/s]
# Epoch 57, Loss: 2.2671
# Pretrain Epoch 58/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 58, Loss: 2.2682
# Pretrain Epoch 59/100: 100%|██████████| 62/62 [00:25<00:00,  2.48it/s]
# Epoch 59, Loss: 2.2636
# Pretrain Epoch 60/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 60, Loss: 2.2670
# Pretrain Epoch 61/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 61, Loss: 2.2650
# Pretrain Epoch 62/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 62, Loss: 2.2641
# Pretrain Epoch 63/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 63, Loss: 2.2647
# Pretrain Epoch 64/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 64, Loss: 2.2629
# Pretrain Epoch 65/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 65, Loss: 2.2624
# Pretrain Epoch 66/100: 100%|██████████| 62/62 [00:24<00:00,  2.50it/s]
# Epoch 66, Loss: 2.2627
# Pretrain Epoch 67/100: 100%|██████████| 62/62 [00:24<00:00,  2.48it/s]
# Epoch 67, Loss: 2.2629
# Pretrain Epoch 68/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 68, Loss: 2.2623
# Pretrain Epoch 69/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 69, Loss: 2.2596
# Pretrain Epoch 70/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 70, Loss: 2.2599
# Pretrain Epoch 71/100: 100%|██████████| 62/62 [00:24<00:00,  2.49it/s]
# Epoch 71, Loss: 2.2603
# Pretrain Epoch 72/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 72, Loss: 2.2600
# Pretrain Epoch 73/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 73, Loss: 2.2590
# Pretrain Epoch 74/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 74, Loss: 2.2589
# Pretrain Epoch 75/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 75, Loss: 2.2592
# Pretrain Epoch 76/100: 100%|██████████| 62/62 [00:24<00:00,  2.48it/s]
# Epoch 76, Loss: 2.2578
# Pretrain Epoch 77/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 77, Loss: 2.2568
# Pretrain Epoch 78/100: 100%|██████████| 62/62 [00:24<00:00,  2.55it/s]
# Epoch 78, Loss: 2.2617
# Pretrain Epoch 79/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 79, Loss: 2.2565
# Pretrain Epoch 80/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 80, Loss: 2.2587
# Pretrain Epoch 81/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 81, Loss: 2.2597
# Pretrain Epoch 82/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 82, Loss: 2.2567
# Pretrain Epoch 83/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 83, Loss: 2.2549
# Pretrain Epoch 84/100: 100%|██████████| 62/62 [00:25<00:00,  2.43it/s]
# Epoch 84, Loss: 2.2558
# Pretrain Epoch 85/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 85, Loss: 2.2577
# Pretrain Epoch 86/100: 100%|██████████| 62/62 [00:25<00:00,  2.45it/s]
# Epoch 86, Loss: 2.2549
# Pretrain Epoch 87/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 87, Loss: 2.2557
# Pretrain Epoch 88/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 88, Loss: 2.2549
# Pretrain Epoch 89/100: 100%|██████████| 62/62 [00:24<00:00,  2.51it/s]
# Epoch 89, Loss: 2.2533
# Pretrain Epoch 90/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 90, Loss: 2.2546
# Pretrain Epoch 91/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 91, Loss: 2.2549
# Pretrain Epoch 92/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 92, Loss: 2.2557
# Pretrain Epoch 93/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 93, Loss: 2.2536
# Pretrain Epoch 94/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 94, Loss: 2.2543
# Pretrain Epoch 95/100: 100%|██████████| 62/62 [00:24<00:00,  2.56it/s]
# Epoch 95, Loss: 2.2530
# Pretrain Epoch 96/100: 100%|██████████| 62/62 [00:24<00:00,  2.58it/s]
# Epoch 96, Loss: 2.2494
# Pretrain Epoch 97/100: 100%|██████████| 62/62 [00:24<00:00,  2.52it/s]
# Epoch 97, Loss: 2.2506
# Pretrain Epoch 98/100: 100%|██████████| 62/62 [00:24<00:00,  2.54it/s]
# Epoch 98, Loss: 2.2527
# Pretrain Epoch 99/100: 100%|██████████| 62/62 [00:24<00:00,  2.57it/s]
# Epoch 99, Loss: 2.2495
# Pretrain Epoch 100/100: 100%|██████████| 62/62 [00:24<00:00,  2.53it/s]
# Epoch 100, Loss: 2.2491

# %%
# Save pretrained model
torch.save(model.state_dict(), 'simclr_pretask_efficientnetb0.pth')

# %%
# Plot pre-training loss
plt.figure(figsize=(8, 6))
plt.plot(pretrain_losses)
plt.title('SimCLR Pre-training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.savefig('pretrain_loss.png')
plt.show()

# %%
# t-SNE Visualization
model.eval()
# Out:
# SimCLR(
#   (encoder): EfficientNet(
#     (features): Sequential(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#       (1): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#               (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (2): Conv2dNormActivation(
#               (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         )
#       )
#       (2): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#         )
#       )
#       (3): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#               (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#         )
#       )
#       (4): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#               (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#         )
#       )
#       (5): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#               (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#         )
#       )
#       (6): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#               (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#         )
#         (1): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#         )
#         (2): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#         )
#         (3): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#         )
#       )
#       (7): Sequential(
#         (0): MBConv(
#           (block): Sequential(
#             (0): Conv2dNormActivation(
#               (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (1): Conv2dNormActivation(
#               (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#               (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): SiLU(inplace=True)
#             )
#             (2): SqueezeExcitation(
#               (avgpool): AdaptiveAvgPool2d(output_size=1)
#               (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#               (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#               (activation): SiLU(inplace=True)
#               (scale_activation): Sigmoid()
#             )
#             (3): Conv2dNormActivation(
#               (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#         )
#       )
#       (8): Conv2dNormActivation(
#         (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): SiLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (classifier): Identity()
#   )
#   (projection_head): Sequential(
#     (0): Linear(in_features=1280, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=512, out_features=128, bias=True)
#   )
# )

# %%
# Use base_dataset subset for t-SNE (PIL, then transform)
tsne_subset = torch.utils.data.Subset(base_dataset, pretrain_indices)
tsne_wrapper = DownstreamWrapper(tsne_subset, transform=downstream_transform)
tsne_loader = DataLoader(tsne_wrapper, batch_size=32, shuffle=False, num_workers=2, pin_memory=True)

features = []
labels = []
with torch.no_grad():
    for batch in tqdm(tsne_loader, desc="Extracting features for t-SNE"):
        img, label = batch  # Single img
        img = img.to(device)
        feature = model.encoder(img)
        feature = feature.view(feature.size(0), -1)
        features.append(feature.cpu().numpy())
        labels.append(label.numpy())
features = np.concatenate(features, axis=0)
labels = np.concatenate(labels, axis=0)

print("Running t-SNE on pretrain dataset features...")
tsne = TSNE(n_components=2, perplexity=30, n_iter=1000, random_state=42, verbose=1)
tsne_features = tsne.fit_transform(features)

plt.figure(figsize=(10, 8))
scatter = plt.scatter(tsne_features[:, 0], tsne_features[:, 1], c=labels, cmap='bwr', alpha=0.5, s=10)
plt.colorbar(scatter, label='Label (0=Non-Cancer, 1=Cancer)')
plt.title('t-SNE of Pretrained SimCLR Features (30% Data)')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.savefig('tsne_simclr_pretrain.png')
plt.show()
print("t-SNE plot saved as 'tsne_simclr_pretrain.png'")
# Out:
# Extracting features for t-SNE: 100%|██████████| 63/63 [00:06<00:00,  9.81it/s]
# Running t-SNE on pretrain dataset features...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.001s...
# [t-SNE] Computed neighbors for 2000 samples in 0.252s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 8.470388
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.891495
# [t-SNE] KL divergence after 1000 iterations: 0.628558
# t-SNE plot saved as 'tsne_simclr_pretrain.png'

# %%
# Downstream classification with SVM
num_epochs_cls = 100
# Extract features from pre-trained encoder
model.eval()
train_features, train_labels = [], []
with torch.no_grad():
    for img, label in train_loader_downstream:
        img = img.to(device)
        feature = model.encoder(img).view(img.size(0), -1).cpu().numpy()
        train_features.append(feature)
        train_labels.append(label.numpy())
train_features = np.concatenate(train_features, axis=0)
train_labels = np.concatenate(train_labels, axis=0)

val_features, val_labels = [], []
with torch.no_grad():
    for img, label in val_loader_downstream:
        img = img.to(device)
        feature = model.encoder(img).view(img.size(0), -1).cpu().numpy()
        val_features.append(feature)
        val_labels.append(label.numpy())
val_features = np.concatenate(val_features, axis=0)
val_labels = np.concatenate(val_labels, axis=0)

# Train SVM
from sklearn.svm import SVC
svm_classifier = SVC(kernel='rbf', random_state=42, probability=True)
svm_classifier.fit(train_features, train_labels)

# Validate
val_pred = svm_classifier.predict(val_features)
val_acc = (val_pred == val_labels).mean()
print(f"Validation Accuracy: {val_acc:.4f}")
# Out:
# Validation Accuracy: 0.8538

# %%
# Test evaluation
test_features, test_labels = [], []
with torch.no_grad():
    for img, label in test_loader:
        img = img.to(device)
        feature = model.encoder(img).view(img.size(0), -1).cpu().numpy()
        test_features.append(feature)
        test_labels.append(label.numpy())
test_features = np.concatenate(test_features, axis=0)
test_labels = np.concatenate(test_labels, axis=0)

test_pred = svm_classifier.predict(test_features)
test_acc = (test_pred == test_labels).mean()
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Test Accuracy: 0.8448

# %%
# Import necessary libraries for visualizations
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, precision_recall_curve
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance

# %%
# Confusion matrix
cm = confusion_matrix(test_labels, test_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Non-Cancer', 'Cancer'], yticklabels=['Non-Cancer', 'Cancer'])
plt.title('Test Confusion Matrix (SVM)')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('test_cm_svm.png')
plt.show()

# %%
# Classification report
print(classification_report(test_labels, test_pred, target_names=['Non-Cancer', 'Cancer']))
# Out:
#               precision    recall  f1-score   support
#
#   Non-Cancer       0.80      0.91      0.85      3981
#       Cancer       0.90      0.78      0.83      4019
#
#     accuracy                           0.84      8000
#    macro avg       0.85      0.85      0.84      8000
# weighted avg       0.85      0.84      0.84      8000

# %%
# ROC Curve
test_prob = svm_classifier.predict_proba(test_features)[:, 1]  # Probability for the positive class (Cancer)
fpr, tpr, _ = roc_curve(test_labels, test_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (SVM)')
plt.legend(loc='lower right')
plt.savefig('roc_curve_svm.png')
plt.show()

# %%
# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(test_labels, test_prob)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='purple', lw=2, label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (SVM)')
plt.legend(loc='lower left')
plt.savefig('pr_curve_svm.png')
plt.show()

# %%
# Optional: Decision Boundary (requires 2D features via t-SNE or PCA)
from sklearn.decomposition import PCA
# Reduce features to 2D using PCA
pca = PCA(n_components=2)
test_features_2d = pca.fit_transform(test_features)

# Train SVM on 2D features
svm_2d = SVC(kernel='rbf', random_state=42)
svm_2d.fit(test_features_2d, test_labels)

# Create mesh grid for decision boundary
h = 0.02  # Step size in the mesh
x_min, x_max = test_features_2d[:, 0].min() - 1, test_features_2d[:, 0].max() + 1
y_min, y_max = test_features_2d[:, 1].min() - 1, test_features_2d[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

# Predict on mesh grid
Z = svm_2d.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot decision boundary
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, cmap=plt.cm.coolwarm, alpha=0.8)
plt.scatter(test_features_2d[:, 0], test_features_2d[:, 1], c=test_labels, cmap=plt.cm.coolwarm, edgecolors='k')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('SVM Decision Boundary (2D PCA Features)')
plt.savefig('decision_boundary_svm.png')
plt.show()
